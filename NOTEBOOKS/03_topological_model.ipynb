# %%
### SETUP ###
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import pickle
from torch.utils.data import DataLoader
from sklearn.metrics import confusion_matrix, classification_report
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

from SCRIPTS.config import *
from SCRIPTS.dataprep import prepare_interval_data, TaskIntervalDataset
from SCRIPTS.topological_model import TopologicalModel
from SCRIPTS.topological_training import train_topological_model
from SCRIPTS.cross_validation_experiments import run_topological_cross_validation

# Visualization setup
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("husl")

# Set random seed
np.random.seed(42)
torch.manual_seed(42)

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Data path: {COMBINED_SCATTERING}")
print(f"Results path: {TOPOLOGICAL_RESULTS_DIR}")
# Out:
# Data path: /Users/judesack/Neurospectrum_Creativity/DATA/SCATTERING_COEFFICIENTS/combined_scattering_data.csv
# Results path: /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/topological_results

# %%
### CONFIGURATION ###

# Train topological models? T/F
TRAIN_TOPOLOGICAL = False

# Run cross-validation? T/F
RUN_CROSS_VALIDATION = True

# Number of CV trials (set to 5)
CV_TRIALS = 5

# Latent dimensions to test
LATENT_DIMS = [8, 48]

# %%
### LOAD INTERVAL DATA ###

print("\n=== LOADING INTERVAL DATA ===")
train_loader_subj, test_loader_subj, info_subj = prepare_interval_data(
    scattering_data_path=COMBINED_SCATTERING,
    split_type='subject',
    batch_size=16,
    random_state=42
)

train_loader_time, test_loader_time, info_time = prepare_interval_data(
    scattering_data_path=COMBINED_SCATTERING,
    split_type='time',
    batch_size=16,
    random_state=42
)

print(f"\nSubject split: {info_subj['n_train']} train, {info_subj['n_test']} test")
print(f"Time split: {info_time['n_train']} train, {info_time['n_test']} test")
# Out:
# === LOADING INTERVAL DATA ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['16101401', '16100801', '15081202sub2', '15053001sub2', '15053001sub1', '16100101', '16100601', '15052902', '14091102', '14101601', '15080601', '14091701', '16102002', '15040901']
#   Test subjects (3): ['15111101', '14092201', '15012001']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
#
# Subject split: 252 train, 54 test
# Time split: 238 train, 68 test

# %%
### TRAIN TOPOLOGICAL MODELS ###

if TRAIN_TOPOLOGICAL:
    print("\n=== TRAINING TOPOLOGICAL MODELS ===")
    
    results = {}
    
    for latent_dim in LATENT_DIMS:
        print(f"\n--- Latent Dimension: {latent_dim} ---")
        results[latent_dim] = {}
        
        print("\nSUBJECT WITHHOLDING:")
        model = TopologicalModel(
            input_dim=768,
            latent_dim=latent_dim,
            num_classes=3
        )
        
        model, history, val_preds, val_labels = train_topological_model(
            model=model,
            train_loader=train_loader_subj,
            test_loader=test_loader_subj,
            num_epochs=DEFAULT_EPOCHS,
            lr=DEFAULT_LEARNING_RATE,
            device=device
        )
        
        val_acc = 100 * np.mean(np.array(val_preds) == np.array(val_labels))
        results[latent_dim]['subject'] = {
            'accuracy': val_acc,
            'predictions': val_preds,
            'labels': val_labels,
            'history': history
        }
        
        print("\nTIME WITHHOLDING:")
        model = TopologicalModel(
            input_dim=768,
            latent_dim=latent_dim,
            num_classes=3
        )
        
        model, history, val_preds, val_labels = train_topological_model(
            model=model,
            train_loader=train_loader_time,
            test_loader=test_loader_time,
            num_epochs=DEFAULT_EPOCHS,
            lr=DEFAULT_LEARNING_RATE,
            device=device
        )
        
        val_acc = 100 * np.mean(np.array(val_preds) == np.array(val_labels))
        results[latent_dim]['time'] = {
            'accuracy': val_acc,
            'predictions': val_preds,
            'labels': val_labels,
            'history': history
        }
    
    save_path = TOPOLOGICAL_RESULTS_DIR / 'topological_training_results.pkl'
    with open(save_path, 'wb') as f:
        pickle.dump(results, f)
    print(f"\n✓ Results saved to {save_path}")
    
    print("\n=== TOPOLOGICAL MODEL RESULTS ===")
    for latent_dim in LATENT_DIMS:
        print(f"\n{latent_dim}D Latent Space:")
        print(f"  Subject: {results[latent_dim]['subject']['accuracy']:.1f}%")
        print(f"  Time: {results[latent_dim]['time']['accuracy']:.1f}%")

else:
    print("✓ Skipping topological model training")
# Out:
# ✓ Skipping topological model training

# %%
### CROSS-VALIDATION ###

if RUN_CROSS_VALIDATION:
    print(f"\n=== CROSS-VALIDATION EXPERIMENTS ({CV_TRIALS} trials) ===")
    
    cv_results = {}
    
    for latent_dim in LATENT_DIMS:
        print(f"\n--- LATENT DIMENSION: {latent_dim} ---")
        cv_results[latent_dim] = {}
        
        for split_type in ['subject', 'time']:
            print(f"\n{split_type.upper()} SPLIT:")
            cv_results[latent_dim][split_type] = run_topological_cross_validation(
                data_path=COMBINED_SCATTERING,
                split_type=split_type,
                latent_dim=latent_dim,
                num_trials=CV_TRIALS,
                num_epochs=DEFAULT_EPOCHS
            )
    
    save_path = TOPOLOGICAL_RESULTS_DIR / 'topological_cv_results.pkl'
    with open(save_path, 'wb') as f:
        pickle.dump(cv_results, f)
    print(f"\n✓ Results saved to {save_path}")
    
    print("\n=== CROSS-VALIDATION SUMMARY ===")
    for latent_dim in LATENT_DIMS:
        print(f"\n{latent_dim}D Latent Space:")
        print(f"  Subject: {cv_results[latent_dim]['subject']['mean_accuracy']:.1f}% ± {cv_results[latent_dim]['subject']['std_accuracy']:.1f}%")
        print(f"  Time: {cv_results[latent_dim]['time']['mean_accuracy']:.1f}% ± {cv_results[latent_dim]['time']['std_accuracy']:.1f}%")

else:
    # Load existing results
    cv_file = TOPOLOGICAL_RESULTS_DIR / 'topological_cv_results.pkl'
    
    if cv_file.exists():
        with open(cv_file, 'rb') as f:
            cv_results = pickle.load(f)
        
        print("✓ Loaded existing cross-validation results")
        
        print("\n=== CROSS-VALIDATION SUMMARY ===")
        for latent_dim in LATENT_DIMS:
            if latent_dim in cv_results:
                print(f"\n{latent_dim}D Latent Space:")
                print(f"  Subject: {cv_results[latent_dim]['subject']['mean_accuracy']:.1f}% ± {cv_results[latent_dim]['subject']['std_accuracy']:.1f}%")
                print(f"  Time: {cv_results[latent_dim]['time']['mean_accuracy']:.1f}% ± {cv_results[latent_dim]['time']['std_accuracy']:.1f}%")
    else:
        print("✓ No existing cross-validation results found")
# Out:
# === CROSS-VALIDATION EXPERIMENTS (5 trials) ===
#
# --- LATENT DIMENSION: 8 ---
#
# SUBJECT SPLIT:
#
# === Topological Model Trial 1/5 (subject split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['16101401', '16100801', '15081202sub2', '15053001sub2', '15053001sub1', '16100101', '16100601', '15052902', '14091102', '14101601', '15080601', '14091701', '16102002', '15040901']
#   Test subjects (3): ['15111101', '14092201', '15012001']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Acc: 40.9%, Val Acc: 22.2%
#   Recon Loss: 0.2278, Class Loss: 1.5158
#   Predicting classes: [2]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 20/100:
#   Train Acc: 53.6%, Val Acc: 55.6%
#   Recon Loss: 0.1369, Class Loss: 1.0603
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 30/100:
#   Train Acc: 54.8%, Val Acc: 55.6%
#   Recon Loss: 0.0965, Class Loss: 1.0299
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 40/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.0929, Class Loss: 1.0283
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 50/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1663, Class Loss: 1.0152
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 60/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0793, Class Loss: 1.0032
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 70/100:
#   Train Acc: 56.0%, Val Acc: 55.6%
#   Recon Loss: 0.0742, Class Loss: 1.0213
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 80/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0684, Class Loss: 1.0113
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 90/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0733, Class Loss: 0.9989
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 100/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0748, Class Loss: 1.0234
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
#
# Final Results:
#   Train Accuracy: 55.6%
#   Val Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
#
# === Topological Model Trial 2/5 (subject split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15052902', '14091701', '16100801', '14101601', '15040901', '16100101', '15081202sub2', '16102002', '16101401', '15080601', '15012001', '14092201', '15111101', '14091102']
#   Test subjects (3): ['15053001sub1', '16100601', '15053001sub2']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Acc: 52.0%, Val Acc: 55.6%
#   Recon Loss: 0.2321, Class Loss: 1.0552
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 20/100:
#   Train Acc: 54.8%, Val Acc: 55.6%
#   Recon Loss: 0.1256, Class Loss: 1.0323
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 30/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1039, Class Loss: 1.0221
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 40/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0974, Class Loss: 1.0010
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 50/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0859, Class Loss: 0.9953
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 60/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0957, Class Loss: 1.0062
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 70/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0843, Class Loss: 0.9989
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 80/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1050, Class Loss: 1.0058
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 90/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.0744, Class Loss: 0.9985
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 100/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0847, Class Loss: 0.9857
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
#
# Final Results:
#   Train Accuracy: 55.6%
#   Val Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
#
# === Topological Model Trial 3/5 (subject split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15080601', '16100601', '16101401', '15040901', '14101601', '15053001sub2', '14091701', '14091102', '15111101', '15052902', '16100801', '15053001sub1', '14092201', '16102002']
#   Test subjects (3): ['15081202sub2', '15012001', '16100101']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Acc: 41.3%, Val Acc: 55.6%
#   Recon Loss: 0.1933, Class Loss: 1.5752
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 20/100:
#   Train Acc: 54.4%, Val Acc: 55.6%
#   Recon Loss: 0.1434, Class Loss: 1.0224
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 30/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1075, Class Loss: 1.0320
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 40/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0923, Class Loss: 1.0211
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 50/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0911, Class Loss: 0.9962
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 60/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1131, Class Loss: 1.0139
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 70/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1310, Class Loss: 1.0057
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 80/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1058, Class Loss: 1.0006
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 90/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0741, Class Loss: 1.0008
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 100/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0741, Class Loss: 0.9963
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
#
# Final Results:
#   Train Accuracy: 55.6%
#   Val Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
#
# === Topological Model Trial 4/5 (subject split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['16100101', '15040901', '15052902', '14092201', '14101601', '15053001sub2', '14091102', '16101401', '15012001', '15111101', '14091701', '16102002', '15081202sub2', '16100801']
#   Test subjects (3): ['15080601', '16100601', '15053001sub1']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Acc: 34.5%, Val Acc: 55.6%
#   Recon Loss: 0.2073, Class Loss: 1.2384
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 20/100:
#   Train Acc: 56.0%, Val Acc: 55.6%
#   Recon Loss: 0.1399, Class Loss: 1.0758
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 30/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1115, Class Loss: 1.0005
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 40/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.0948, Class Loss: 1.0199
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 50/100:
#   Train Acc: 54.8%, Val Acc: 55.6%
#   Recon Loss: 0.0847, Class Loss: 1.0323
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 60/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.0824, Class Loss: 1.0221
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 70/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1315, Class Loss: 1.0260
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 80/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0817, Class Loss: 1.0256
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 90/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0790, Class Loss: 1.0013
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 100/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0790, Class Loss: 0.9981
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
#
# Final Results:
#   Train Accuracy: 55.6%
#   Val Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
#
# === Topological Model Trial 5/5 (subject split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15081202sub2', '14091701', '16100601', '15040901', '15053001sub1', '16101401', '16100801', '15111101', '16100101', '16102002', '15080601', '14091102', '15053001sub2', '15012001']
#   Test subjects (3): ['14092201', '14101601', '15052902']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Acc: 48.0%, Val Acc: 55.6%
#   Recon Loss: 0.2295, Class Loss: 1.2131
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 20/100:
#   Train Acc: 53.6%, Val Acc: 55.6%
#   Recon Loss: 0.1337, Class Loss: 1.0669
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 30/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1046, Class Loss: 1.0193
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 40/100:
#   Train Acc: 56.0%, Val Acc: 55.6%
#   Recon Loss: 0.1252, Class Loss: 1.0165
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 50/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0916, Class Loss: 1.0155
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 60/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1243, Class Loss: 1.0090
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 70/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0917, Class Loss: 0.9985
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 80/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0854, Class Loss: 1.0281
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 90/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0858, Class Loss: 0.9990
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 100/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.0803, Class Loss: 0.9967
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
#
# Final Results:
#   Train Accuracy: 55.2%
#   Val Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
# Results saved to: /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/topological_results/topological_subject_8d_cv_results.pkl
#
# === Topological Results (subject split, 8D) ===
# Accuracy: 55.6% ± 0.0%
#
# TIME SPLIT:
#
# === Topological Model Trial 1/5 (time split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Acc: 46.6%, Val Acc: 50.0%
#   Recon Loss: 0.2423, Class Loss: 1.1965
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 20/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.1583, Class Loss: 1.0042
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 30/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.1090, Class Loss: 1.0167
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 40/100:
#   Train Acc: 57.6%, Val Acc: 50.0%
#   Recon Loss: 0.1359, Class Loss: 0.9912
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 50/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0945, Class Loss: 0.9977
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 60/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0831, Class Loss: 0.9903
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 70/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0872, Class Loss: 0.9666
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 80/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1239, Class Loss: 0.9857
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 90/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0932, Class Loss: 0.9788
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 100/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0810, Class Loss: 0.9854
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
#
# Final Results:
#   Train Accuracy: 57.1%
#   Val Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
#
# === Topological Model Trial 2/5 (time split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Acc: 52.1%, Val Acc: 50.0%
#   Recon Loss: 0.2837, Class Loss: 1.1448
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 20/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1459, Class Loss: 1.0234
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 30/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1293, Class Loss: 0.9963
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 40/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.1170, Class Loss: 0.9987
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 50/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1089, Class Loss: 0.9842
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 60/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0928, Class Loss: 0.9822
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 70/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1728, Class Loss: 0.9775
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 80/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0960, Class Loss: 0.9898
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 90/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0864, Class Loss: 1.0024
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 100/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1008, Class Loss: 0.9875
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
#
# Final Results:
#   Train Accuracy: 57.1%
#   Val Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
#
# === Topological Model Trial 3/5 (time split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Acc: 44.1%, Val Acc: 25.0%
#   Recon Loss: 0.2416, Class Loss: 1.7148
#   Predicting classes: [1]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 20/100:
#   Train Acc: 57.6%, Val Acc: 50.0%
#   Recon Loss: 0.1581, Class Loss: 1.0113
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 30/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1430, Class Loss: 1.0076
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 40/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1031, Class Loss: 0.9939
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 50/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0940, Class Loss: 1.0009
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 60/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0959, Class Loss: 0.9905
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 70/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1295, Class Loss: 0.9773
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 80/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.0812, Class Loss: 0.9985
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 90/100:
#   Train Acc: 57.6%, Val Acc: 50.0%
#   Recon Loss: 0.0748, Class Loss: 0.9829
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 100/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1098, Class Loss: 0.9911
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
#
# Final Results:
#   Train Accuracy: 57.1%
#   Val Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
#
# === Topological Model Trial 4/5 (time split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Acc: 54.6%, Val Acc: 50.0%
#   Recon Loss: 0.2507, Class Loss: 1.0520
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 20/100:
#   Train Acc: 55.9%, Val Acc: 50.0%
#   Recon Loss: 0.1623, Class Loss: 1.0473
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 30/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1203, Class Loss: 1.0093
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 40/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1411, Class Loss: 0.9848
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 50/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1086, Class Loss: 0.9965
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 60/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.0904, Class Loss: 0.9860
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 70/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1362, Class Loss: 0.9772
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 80/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0868, Class Loss: 0.9886
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 90/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0887, Class Loss: 0.9939
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 100/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.1344, Class Loss: 0.9862
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
#
# Final Results:
#   Train Accuracy: 56.7%
#   Val Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
#
# === Topological Model Trial 5/5 (time split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Acc: 41.2%, Val Acc: 50.0%
#   Recon Loss: 0.2474, Class Loss: 1.1717
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 20/100:
#   Train Acc: 58.0%, Val Acc: 50.0%
#   Recon Loss: 0.1461, Class Loss: 0.9838
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 30/100:
#   Train Acc: 57.6%, Val Acc: 50.0%
#   Recon Loss: 0.1289, Class Loss: 1.0210
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 40/100:
#   Train Acc: 57.6%, Val Acc: 50.0%
#   Recon Loss: 0.1044, Class Loss: 0.9977
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 50/100:
#   Train Acc: 57.6%, Val Acc: 50.0%
#   Recon Loss: 0.1453, Class Loss: 0.9972
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 60/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1683, Class Loss: 0.9937
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 70/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0885, Class Loss: 0.9903
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 80/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1061, Class Loss: 0.9703
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 90/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1746, Class Loss: 0.9949
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 100/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.1055, Class Loss: 0.9702
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
#
# Final Results:
#   Train Accuracy: 56.7%
#   Val Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
# Results saved to: /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/topological_results/topological_time_8d_cv_results.pkl
#
# === Topological Results (time split, 8D) ===
# Accuracy: 50.0% ± 0.0%
#
# --- LATENT DIMENSION: 48 ---
#
# SUBJECT SPLIT:
#
# === Topological Model Trial 1/5 (subject split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['16101401', '16100801', '15081202sub2', '15053001sub2', '15053001sub1', '16100101', '16100601', '15052902', '14091102', '14101601', '15080601', '14091701', '16102002', '15040901']
#   Test subjects (3): ['15111101', '14092201', '15012001']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Acc: 51.2%, Val Acc: 22.2%
#   Recon Loss: 0.2495, Class Loss: 1.4521
#   Predicting classes: [1]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 20/100:
#   Train Acc: 55.2%, Val Acc: 22.2%
#   Recon Loss: 0.2239, Class Loss: 1.0535
#   Predicting classes: [0 1 2]
# Epoch 30/100:
#   Train Acc: 55.2%, Val Acc: 42.6%
#   Recon Loss: 0.1460, Class Loss: 1.0538
#   Predicting classes: [0 2]
#   ⚠️  Mode collapse detected! Only predicting 2 classes
# Epoch 40/100:
#   Train Acc: 55.6%, Val Acc: 53.7%
#   Recon Loss: 0.1056, Class Loss: 1.0305
#   Predicting classes: [0 1]
#   ⚠️  Mode collapse detected! Only predicting 2 classes
# Epoch 50/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.0940, Class Loss: 1.0147
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 60/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1011, Class Loss: 0.9998
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 70/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.1199, Class Loss: 1.0128
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 80/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0891, Class Loss: 0.9946
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 90/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0822, Class Loss: 1.0046
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 100/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0686, Class Loss: 0.9959
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
#
# Final Results:
#   Train Accuracy: 55.6%
#   Val Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
#
# === Topological Model Trial 2/5 (subject split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15052902', '14091701', '16100801', '14101601', '15040901', '16100101', '15081202sub2', '16102002', '16101401', '15080601', '15012001', '14092201', '15111101', '14091102']
#   Test subjects (3): ['15053001sub1', '16100601', '15053001sub2']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Acc: 35.3%, Val Acc: 55.6%
#   Recon Loss: 0.2396, Class Loss: 3.0478
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 20/100:
#   Train Acc: 54.0%, Val Acc: 55.6%
#   Recon Loss: 0.2061, Class Loss: 1.1237
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 30/100:
#   Train Acc: 54.8%, Val Acc: 55.6%
#   Recon Loss: 0.1234, Class Loss: 1.0425
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 40/100:
#   Train Acc: 54.8%, Val Acc: 55.6%
#   Recon Loss: 0.1010, Class Loss: 1.0537
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 50/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.2724, Class Loss: 0.9806
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 60/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1408, Class Loss: 1.0107
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 70/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.1250, Class Loss: 1.0011
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 80/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0998, Class Loss: 1.0076
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 90/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0873, Class Loss: 1.0022
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 100/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0728, Class Loss: 1.0124
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
#
# Final Results:
#   Train Accuracy: 55.6%
#   Val Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
#
# === Topological Model Trial 3/5 (subject split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15080601', '16100601', '16101401', '15040901', '14101601', '15053001sub2', '14091701', '14091102', '15111101', '15052902', '16100801', '15053001sub1', '14092201', '16102002']
#   Test subjects (3): ['15081202sub2', '15012001', '16100101']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Acc: 32.5%, Val Acc: 55.6%
#   Recon Loss: 0.2555, Class Loss: 2.4825
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 20/100:
#   Train Acc: 54.4%, Val Acc: 55.6%
#   Recon Loss: 0.1491, Class Loss: 1.0944
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 30/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1179, Class Loss: 1.0306
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 40/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.1288, Class Loss: 1.0440
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 50/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.1211, Class Loss: 1.0838
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 60/100:
#   Train Acc: 54.8%, Val Acc: 55.6%
#   Recon Loss: 0.0916, Class Loss: 1.0318
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 70/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1304, Class Loss: 1.0032
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 80/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.2455, Class Loss: 1.0122
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 90/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.1947, Class Loss: 1.0064
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 100/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1185, Class Loss: 1.0092
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
#
# Final Results:
#   Train Accuracy: 55.6%
#   Val Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
#
# === Topological Model Trial 4/5 (subject split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['16100101', '15040901', '15052902', '14092201', '14101601', '15053001sub2', '14091102', '16101401', '15012001', '15111101', '14091701', '16102002', '15081202sub2', '16100801']
#   Test subjects (3): ['15080601', '16100601', '15053001sub1']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Acc: 33.7%, Val Acc: 22.2%
#   Recon Loss: 0.2474, Class Loss: 2.5315
#   Predicting classes: [1 2]
#   ⚠️  Mode collapse detected! Only predicting 2 classes
# Epoch 20/100:
#   Train Acc: 54.8%, Val Acc: 46.3%
#   Recon Loss: 0.1905, Class Loss: 1.0929
#   Predicting classes: [0 1]
#   ⚠️  Mode collapse detected! Only predicting 2 classes
# Epoch 30/100:
#   Train Acc: 54.8%, Val Acc: 53.7%
#   Recon Loss: 0.1236, Class Loss: 1.0929
#   Predicting classes: [0 1]
#   ⚠️  Mode collapse detected! Only predicting 2 classes
# Epoch 40/100:
#   Train Acc: 55.6%, Val Acc: 51.9%
#   Recon Loss: 0.1036, Class Loss: 1.0584
#   Predicting classes: [0 1]
#   ⚠️  Mode collapse detected! Only predicting 2 classes
# Epoch 50/100:
#   Train Acc: 55.2%, Val Acc: 51.9%
#   Recon Loss: 0.1650, Class Loss: 1.0363
#   Predicting classes: [0 1]
#   ⚠️  Mode collapse detected! Only predicting 2 classes
# Epoch 60/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1456, Class Loss: 1.0242
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 70/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1112, Class Loss: 1.0034
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 80/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0895, Class Loss: 1.0410
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 90/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0869, Class Loss: 0.9919
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 100/100:
#   Train Acc: 54.8%, Val Acc: 55.6%
#   Recon Loss: 0.0860, Class Loss: 1.0301
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
#
# Final Results:
#   Train Accuracy: 54.8%
#   Val Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
#
# === Topological Model Trial 5/5 (subject split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15081202sub2', '14091701', '16100601', '15040901', '15053001sub1', '16101401', '16100801', '15111101', '16100101', '16102002', '15080601', '14091102', '15053001sub2', '15012001']
#   Test subjects (3): ['14092201', '14101601', '15052902']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Acc: 37.3%, Val Acc: 22.2%
#   Recon Loss: 0.2324, Class Loss: 2.2539
#   Predicting classes: [1]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 20/100:
#   Train Acc: 54.8%, Val Acc: 55.6%
#   Recon Loss: 0.1842, Class Loss: 1.0950
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 30/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.1319, Class Loss: 1.1783
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 40/100:
#   Train Acc: 53.6%, Val Acc: 55.6%
#   Recon Loss: 0.1326, Class Loss: 1.0312
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 50/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1956, Class Loss: 1.1423
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 60/100:
#   Train Acc: 56.0%, Val Acc: 55.6%
#   Recon Loss: 0.1745, Class Loss: 1.0065
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 70/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1183, Class Loss: 0.9988
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 80/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.1143, Class Loss: 1.0044
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 90/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0758, Class Loss: 0.9921
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 100/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0698, Class Loss: 1.0042
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
#
# Final Results:
#   Train Accuracy: 55.6%
#   Val Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
# Results saved to: /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/topological_results/topological_subject_48d_cv_results.pkl
#
# === Topological Results (subject split, 48D) ===
# Accuracy: 55.6% ± 0.0%
#
# TIME SPLIT:
#
# === Topological Model Trial 1/5 (time split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Acc: 28.2%, Val Acc: 16.2%
#   Recon Loss: 0.2547, Class Loss: 1.7322
#   Predicting classes: [1 2]
#   ⚠️  Mode collapse detected! Only predicting 2 classes
# Epoch 20/100:
#   Train Acc: 57.1%, Val Acc: 41.2%
#   Recon Loss: 0.1906, Class Loss: 1.1901
#   Predicting classes: [0 2]
#   ⚠️  Mode collapse detected! Only predicting 2 classes
# Epoch 30/100:
#   Train Acc: 57.1%, Val Acc: 47.1%
#   Recon Loss: 0.1572, Class Loss: 1.0655
#   Predicting classes: [0 2]
#   ⚠️  Mode collapse detected! Only predicting 2 classes
# Epoch 40/100:
#   Train Acc: 57.1%, Val Acc: 47.1%
#   Recon Loss: 0.1242, Class Loss: 1.0438
#   Predicting classes: [0 2]
#   ⚠️  Mode collapse detected! Only predicting 2 classes
# Epoch 50/100:
#   Train Acc: 57.1%, Val Acc: 47.1%
#   Recon Loss: 0.1145, Class Loss: 1.0376
#   Predicting classes: [0 2]
#   ⚠️  Mode collapse detected! Only predicting 2 classes
# Epoch 60/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1061, Class Loss: 1.0115
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 70/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1017, Class Loss: 1.0221
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 80/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.0977, Class Loss: 1.0614
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 90/100:
#   Train Acc: 56.3%, Val Acc: 50.0%
#   Recon Loss: 0.0968, Class Loss: 1.0078
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 100/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0905, Class Loss: 1.0112
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
#
# Final Results:
#   Train Accuracy: 57.1%
#   Val Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
#
# === Topological Model Trial 2/5 (time split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Acc: 52.9%, Val Acc: 47.1%
#   Recon Loss: 0.3019, Class Loss: 1.2083
#   Predicting classes: [0 1]
#   ⚠️  Mode collapse detected! Only predicting 2 classes
# Epoch 20/100:
#   Train Acc: 55.5%, Val Acc: 44.1%
#   Recon Loss: 0.2263, Class Loss: 1.0996
#   Predicting classes: [0 1]
#   ⚠️  Mode collapse detected! Only predicting 2 classes
# Epoch 30/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.1657, Class Loss: 1.0252
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 40/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1217, Class Loss: 0.9900
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 50/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1168, Class Loss: 0.9858
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 60/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0961, Class Loss: 0.9761
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 70/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0837, Class Loss: 0.9921
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 80/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0834, Class Loss: 0.9791
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 90/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0875, Class Loss: 0.9839
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 100/100:
#   Train Acc: 57.6%, Val Acc: 50.0%
#   Recon Loss: 0.0993, Class Loss: 0.9722
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
#
# Final Results:
#   Train Accuracy: 57.6%
#   Val Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
#
# === Topological Model Trial 3/5 (time split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Acc: 43.3%, Val Acc: 48.5%
#   Recon Loss: 0.2811, Class Loss: 1.9926
#   Predicting classes: [0 1]
#   ⚠️  Mode collapse detected! Only predicting 2 classes
# Epoch 20/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.1609, Class Loss: 1.0721
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 30/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.1551, Class Loss: 1.0191
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 40/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1060, Class Loss: 1.0356
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 50/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1653, Class Loss: 1.0239
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 60/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.2682, Class Loss: 0.9917
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 70/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.1513, Class Loss: 0.9737
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 80/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1202, Class Loss: 1.0007
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 90/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.0947, Class Loss: 1.0128
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 100/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.0837, Class Loss: 0.9855
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
#
# Final Results:
#   Train Accuracy: 56.7%
#   Val Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
#
# === Topological Model Trial 4/5 (time split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Acc: 45.0%, Val Acc: 50.0%
#   Recon Loss: 0.2837, Class Loss: 2.0621
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 20/100:
#   Train Acc: 52.1%, Val Acc: 50.0%
#   Recon Loss: 0.1766, Class Loss: 1.1406
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 30/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1394, Class Loss: 1.1063
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 40/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.1179, Class Loss: 1.0162
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 50/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1012, Class Loss: 0.9712
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 60/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.1783, Class Loss: 1.0032
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 70/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1482, Class Loss: 1.0300
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 80/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.2153, Class Loss: 0.9931
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 90/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1355, Class Loss: 0.9714
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 100/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1460, Class Loss: 0.9772
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
#
# Final Results:
#   Train Accuracy: 57.1%
#   Val Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
#
# === Topological Model Trial 5/5 (time split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Acc: 51.7%, Val Acc: 26.5%
#   Recon Loss: 0.2402, Class Loss: 1.7539
#   Predicting classes: [0 1]
#   ⚠️  Mode collapse detected! Only predicting 2 classes
# Epoch 20/100:
#   Train Acc: 56.3%, Val Acc: 48.5%
#   Recon Loss: 0.1893, Class Loss: 1.0873
#   Predicting classes: [0 1]
#   ⚠️  Mode collapse detected! Only predicting 2 classes
# Epoch 30/100:
#   Train Acc: 57.1%, Val Acc: 48.5%
#   Recon Loss: 0.1328, Class Loss: 1.0199
#   Predicting classes: [0 1]
#   ⚠️  Mode collapse detected! Only predicting 2 classes
# Epoch 40/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1095, Class Loss: 1.0061
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 50/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0989, Class Loss: 0.9875
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 60/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0930, Class Loss: 0.9972
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 70/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0894, Class Loss: 0.9832
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 80/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.1601, Class Loss: 1.0152
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 90/100:
#   Train Acc: 58.0%, Val Acc: 50.0%
#   Recon Loss: 0.1332, Class Loss: 0.9884
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
# Epoch 100/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1187, Class Loss: 0.9798
#   Predicting classes: [0]
#   ⚠️  Mode collapse detected! Only predicting 1 classes
#
# Final Results:
#   Train Accuracy: 57.1%
#   Val Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
# Results saved to: /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/topological_results/topological_time_48d_cv_results.pkl
#
# === Topological Results (time split, 48D) ===
# Accuracy: 50.0% ± 0.0%
#
# ✓ Results saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/topological_results/topological_cv_results.pkl
#
# === CROSS-VALIDATION SUMMARY ===
#
# 8D Latent Space:
#   Subject: 55.6% ± 0.0%
#   Time: 50.0% ± 0.0%
#
# 48D Latent Space:
#   Subject: 55.6% ± 0.0%
#   Time: 50.0% ± 0.0%
