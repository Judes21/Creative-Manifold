# %%
### SETUP ###
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import pickle
from torch.utils.data import DataLoader
from sklearn.metrics import confusion_matrix, classification_report
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

from SCRIPTS.config import *
from SCRIPTS.dataprep import prepare_interval_data, TaskIntervalDataset
from SCRIPTS.topological_model import TopologicalModel
from SCRIPTS.topological_training import train_topological_model
from SCRIPTS.cross_validation_experiments import run_topological_cross_validation

# Visualization setup
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("husl")

# Set random seed
np.random.seed(42)
torch.manual_seed(42)

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Data path: {COMBINED_SCATTERING}")
print(f"Results path: {TOPOLOGICAL_RESULTS_DIR}")
# Out:
# Data path: /Users/judesack/Neurospectrum_Creativity/DATA/SCATTERING_COEFFICIENTS/combined_scattering_data.csv
# Results path: /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/topological_results

# %%
### CONFIGURATION ###

# Train topological models? T/F
TRAIN_TOPOLOGICAL = False

# Run cross-validation? T/F
RUN_CROSS_VALIDATION = True

# Number of CV trials (set to 5)
CV_TRIALS = 5

# Latent dimensions to test
LATENT_DIMS = [8, 48]

# %%
### LOAD INTERVAL DATA ###

print("\n=== LOADING INTERVAL DATA ===")
train_loader_subj, test_loader_subj, info_subj = prepare_interval_data(
    scattering_data_path=COMBINED_SCATTERING,
    split_type='subject',
    batch_size=16,
    random_state=42
)

train_loader_time, test_loader_time, info_time = prepare_interval_data(
    scattering_data_path=COMBINED_SCATTERING,
    split_type='time',
    batch_size=16,
    random_state=42
)

print(f"\nSubject split: {info_subj['n_train']} train, {info_subj['n_test']} test")
print(f"Time split: {info_time['n_train']} train, {info_time['n_test']} test")
# Out:
# === LOADING INTERVAL DATA ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15040901', '14091701', '15111101', '15052902', '16100101', '14091102', '16100801', '16101401', '16100601', '16102002', '14092201', '15081202sub2', '15053001sub2', '15080601']
#   Test subjects (3): ['15053001sub1', '15012001', '14101601']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
#
# Subject split: 252 train, 54 test
# Time split: 238 train, 68 test

# %%
### TRAIN TOPOLOGICAL MODELS ###

if TRAIN_TOPOLOGICAL:
    print("\n=== TRAINING TOPOLOGICAL MODELS ===")
    
    results = {}
    
    for latent_dim in LATENT_DIMS:
        print(f"\n--- Latent Dimension: {latent_dim} ---")
        results[latent_dim] = {}
        
        print("\nSUBJECT WITHHOLDING:")
        model = TopologicalModel(
            input_dim=768,
            latent_dim=latent_dim,
            num_classes=3
        )
        
        model, history, val_preds, val_labels = train_topological_model(
            model=model,
            train_loader=train_loader_subj,
            test_loader=test_loader_subj,
            num_epochs=DEFAULT_EPOCHS,
            lr=DEFAULT_LEARNING_RATE,
            device=device
        )
        
        val_acc = 100 * np.mean(np.array(val_preds) == np.array(val_labels))
        results[latent_dim]['subject'] = {
            'accuracy': val_acc,
            'predictions': val_preds,
            'labels': val_labels,
            'history': history
        }
        
        print("\nTIME WITHHOLDING:")
        model = TopologicalModel(
            input_dim=768,
            latent_dim=latent_dim,
            num_classes=3
        )
        
        model, history, val_preds, val_labels = train_topological_model(
            model=model,
            train_loader=train_loader_time,
            test_loader=test_loader_time,
            num_epochs=DEFAULT_EPOCHS,
            lr=DEFAULT_LEARNING_RATE,
            device=device
        )
        
        val_acc = 100 * np.mean(np.array(val_preds) == np.array(val_labels))
        results[latent_dim]['time'] = {
            'accuracy': val_acc,
            'predictions': val_preds,
            'labels': val_labels,
            'history': history
        }
    
    save_path = TOPOLOGICAL_RESULTS_DIR / 'topological_training_results.pkl'
    with open(save_path, 'wb') as f:
        pickle.dump(results, f)
    print(f"\n✓ Results saved to {save_path}")
    
    print("\n=== TOPOLOGICAL MODEL RESULTS ===")
    for latent_dim in LATENT_DIMS:
        print(f"\n{latent_dim}D Latent Space:")
        print(f"  Subject: {results[latent_dim]['subject']['accuracy']:.1f}%")
        print(f"  Time: {results[latent_dim]['time']['accuracy']:.1f}%")

else:
    print("✓ Skipping topological model training")
# Out:
# ✓ Skipping topological model training

# %%
### CROSS-VALIDATION ###

if RUN_CROSS_VALIDATION:
    print(f"\n=== CROSS-VALIDATION EXPERIMENTS ({CV_TRIALS} trials) ===")
    
    cv_results = {}
    
    for latent_dim in LATENT_DIMS:
        print(f"\n--- LATENT DIMENSION: {latent_dim} ---")
        cv_results[latent_dim] = {}
        
        for split_type in ['subject', 'time']:
            print(f"\n{split_type.upper()} SPLIT:")
            cv_results[latent_dim][split_type] = run_topological_cross_validation(
                data_path=COMBINED_SCATTERING,
                split_type=split_type,
                latent_dim=latent_dim,
                num_trials=CV_TRIALS,
                num_epochs=DEFAULT_EPOCHS
            )
    
    save_path = TOPOLOGICAL_RESULTS_DIR / 'topological_cv_results.pkl'
    with open(save_path, 'wb') as f:
        pickle.dump(cv_results, f)
    print(f"\n✓ Results saved to {save_path}")
    
    print("\n=== CROSS-VALIDATION SUMMARY ===")
    for latent_dim in LATENT_DIMS:
        print(f"\n{latent_dim}D Latent Space:")
        print(f"  Subject: {cv_results[latent_dim]['subject']['mean_accuracy']:.1f}% ± {cv_results[latent_dim]['subject']['std_accuracy']:.1f}%")
        print(f"  Time: {cv_results[latent_dim]['time']['mean_accuracy']:.1f}% ± {cv_results[latent_dim]['time']['std_accuracy']:.1f}%")

else:
    # Load existing results
    cv_file = TOPOLOGICAL_RESULTS_DIR / 'topological_cv_results.pkl'
    
    if cv_file.exists():
        with open(cv_file, 'rb') as f:
            cv_results = pickle.load(f)
        
        print("✓ Loaded existing cross-validation results")
        
        print("\n=== CROSS-VALIDATION SUMMARY ===")
        for latent_dim in LATENT_DIMS:
            if latent_dim in cv_results:
                print(f"\n{latent_dim}D Latent Space:")
                print(f"  Subject: {cv_results[latent_dim]['subject']['mean_accuracy']:.1f}% ± {cv_results[latent_dim]['subject']['std_accuracy']:.1f}%")
                print(f"  Time: {cv_results[latent_dim]['time']['mean_accuracy']:.1f}% ± {cv_results[latent_dim]['time']['std_accuracy']:.1f}%")
    else:
        print("✓ No existing cross-validation results found")
# Out:
# === CROSS-VALIDATION EXPERIMENTS (5 trials) ===
#
# --- LATENT DIMENSION: 8 ---
#
# SUBJECT SPLIT:
#
# === Topological Model Trial 1/5 (subject split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15040901', '14091701', '15111101', '15052902', '16100101', '14091102', '16100801', '16101401', '16100601', '16102002', '14092201', '15081202sub2', '15053001sub2', '15080601']
#   Test subjects (3): ['15053001sub1', '15012001', '14101601']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Acc: 40.9%, Val Acc: 55.6%
#   Recon Loss: 0.2253, Class Loss: 1.4591
#   Predicting classes: [0]
# Epoch 20/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1343, Class Loss: 1.0188
#   Predicting classes: [0]
# Epoch 30/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.1113, Class Loss: 0.9937
#   Predicting classes: [0]
# Epoch 40/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1282, Class Loss: 1.0148
#   Predicting classes: [0]
# Epoch 50/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1069, Class Loss: 1.0197
#   Predicting classes: [0]
# Epoch 60/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1092, Class Loss: 1.0019
#   Predicting classes: [0]
# Epoch 70/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0904, Class Loss: 0.9906
#   Predicting classes: [0]
# Epoch 80/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0854, Class Loss: 1.0089
#   Predicting classes: [0]
# Epoch 90/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1038, Class Loss: 0.9979
#   Predicting classes: [0]
# Epoch 100/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0801, Class Loss: 0.9945
#   Predicting classes: [0]
#
# Final Results:
#   Train Accuracy: 55.6%
#   Val Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/topological/attention_subject_topological_8D_trial0.pth
#
# === Topological Model Trial 2/5 (subject split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['16101401', '15081202sub2', '14091701', '16102002', '15080601', '14091102', '15111101', '15053001sub2', '15040901', '14092201', '14101601', '15012001', '15053001sub1', '16100601']
#   Test subjects (3): ['16100101', '16100801', '15052902']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Acc: 46.8%, Val Acc: 55.6%
#   Recon Loss: 0.2360, Class Loss: 1.1574
#   Predicting classes: [0]
# Epoch 20/100:
#   Train Acc: 56.0%, Val Acc: 55.6%
#   Recon Loss: 0.1440, Class Loss: 1.0504
#   Predicting classes: [0]
# Epoch 30/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.1141, Class Loss: 1.0578
#   Predicting classes: [0]
# Epoch 40/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1011, Class Loss: 1.0151
#   Predicting classes: [0]
# Epoch 50/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0853, Class Loss: 1.0136
#   Predicting classes: [0]
# Epoch 60/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.0879, Class Loss: 1.0193
#   Predicting classes: [0]
# Epoch 70/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0770, Class Loss: 1.0059
#   Predicting classes: [0]
# Epoch 80/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0759, Class Loss: 1.0035
#   Predicting classes: [0]
# Epoch 90/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0830, Class Loss: 0.9984
#   Predicting classes: [0]
# Epoch 100/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0956, Class Loss: 1.0118
#   Predicting classes: [0]
#
# Final Results:
#   Train Accuracy: 55.6%
#   Val Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/topological/attention_subject_topological_8D_trial1.pth
#
# === Topological Model Trial 3/5 (subject split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['14092201', '16100801', '15040901', '15080601', '16102002', '15052902', '15081202sub2', '16100601', '15053001sub1', '16101401', '14091701', '16100101', '15012001', '15053001sub2']
#   Test subjects (3): ['15111101', '14101601', '14091102']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Acc: 32.1%, Val Acc: 51.9%
#   Recon Loss: 0.2635, Class Loss: 1.2211
#   Predicting classes: [0 1]
# Epoch 20/100:
#   Train Acc: 52.8%, Val Acc: 55.6%
#   Recon Loss: 0.1712, Class Loss: 1.0957
#   Predicting classes: [0]
# Epoch 30/100:
#   Train Acc: 56.0%, Val Acc: 55.6%
#   Recon Loss: 0.1165, Class Loss: 1.0232
#   Predicting classes: [0]
# Epoch 40/100:
#   Train Acc: 56.0%, Val Acc: 55.6%
#   Recon Loss: 0.1023, Class Loss: 0.9953
#   Predicting classes: [0]
# Epoch 50/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0961, Class Loss: 1.0067
#   Predicting classes: [0]
# Epoch 60/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0902, Class Loss: 0.9819
#   Predicting classes: [0]
# Epoch 70/100:
#   Train Acc: 56.0%, Val Acc: 55.6%
#   Recon Loss: 0.1291, Class Loss: 1.0047
#   Predicting classes: [0]
# Epoch 80/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0938, Class Loss: 0.9907
#   Predicting classes: [0]
# Epoch 90/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0804, Class Loss: 1.0054
#   Predicting classes: [0]
# Epoch 100/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0718, Class Loss: 1.0282
#   Predicting classes: [0]
#
# Final Results:
#   Train Accuracy: 55.6%
#   Val Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/topological/attention_subject_topological_8D_trial2.pth
#
# === Topological Model Trial 4/5 (subject split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['14091102', '15080601', '16101401', '15012001', '16102002', '15052902', '16100601', '15040901', '14101601', '15053001sub1', '15081202sub2', '15053001sub2', '15111101', '14091701']
#   Test subjects (3): ['14092201', '16100801', '16100101']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Acc: 40.1%, Val Acc: 22.2%
#   Recon Loss: 0.2415, Class Loss: 1.8519
#   Predicting classes: [1]
# Epoch 20/100:
#   Train Acc: 45.6%, Val Acc: 50.0%
#   Recon Loss: 0.1540, Class Loss: 1.0790
#   Predicting classes: [0 2]
# Epoch 30/100:
#   Train Acc: 52.4%, Val Acc: 55.6%
#   Recon Loss: 0.1099, Class Loss: 1.0434
#   Predicting classes: [0]
# Epoch 40/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1021, Class Loss: 1.0186
#   Predicting classes: [0]
# Epoch 50/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0901, Class Loss: 1.0128
#   Predicting classes: [0]
# Epoch 60/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0930, Class Loss: 1.0375
#   Predicting classes: [0]
# Epoch 70/100:
#   Train Acc: 56.0%, Val Acc: 55.6%
#   Recon Loss: 0.0970, Class Loss: 0.9886
#   Predicting classes: [0]
# Epoch 80/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0841, Class Loss: 1.0176
#   Predicting classes: [0]
# Epoch 90/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0736, Class Loss: 1.0127
#   Predicting classes: [0]
# Epoch 100/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0819, Class Loss: 1.0206
#   Predicting classes: [0]
#
# Final Results:
#   Train Accuracy: 55.6%
#   Val Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/topological/attention_subject_topological_8D_trial3.pth
#
# === Topological Model Trial 5/5 (subject split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15111101', '15081202sub2', '16100801', '15080601', '16100101', '15040901', '14091701', '15053001sub1', '14091102', '15053001sub2', '14092201', '16100601', '15052902', '14101601']
#   Test subjects (3): ['15012001', '16102002', '16101401']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Acc: 40.9%, Val Acc: 55.6%
#   Recon Loss: 0.2722, Class Loss: 1.1528
#   Predicting classes: [0]
# Epoch 20/100:
#   Train Acc: 56.3%, Val Acc: 55.6%
#   Recon Loss: 0.1439, Class Loss: 1.0194
#   Predicting classes: [0]
# Epoch 30/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1270, Class Loss: 1.0129
#   Predicting classes: [0]
# Epoch 40/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1083, Class Loss: 1.0234
#   Predicting classes: [0]
# Epoch 50/100:
#   Train Acc: 56.0%, Val Acc: 55.6%
#   Recon Loss: 0.1133, Class Loss: 1.0132
#   Predicting classes: [0]
# Epoch 60/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.0927, Class Loss: 1.0109
#   Predicting classes: [0]
# Epoch 70/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0913, Class Loss: 1.0027
#   Predicting classes: [0]
# Epoch 80/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1231, Class Loss: 1.0102
#   Predicting classes: [0]
# Epoch 90/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1066, Class Loss: 0.9887
#   Predicting classes: [0]
# Epoch 100/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0812, Class Loss: 0.9942
#   Predicting classes: [0]
#
# Final Results:
#   Train Accuracy: 55.6%
#   Val Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/topological/attention_subject_topological_8D_trial4.pth
# Results saved to: /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/topological_results/topological_subject_8d_cv_results.pkl
#
# === Topological Results (subject split, 8D) ===
# Accuracy: 55.6% ± 0.0%
#
# TIME SPLIT:
#
# === Topological Model Trial 1/5 (time split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Acc: 45.0%, Val Acc: 50.0%
#   Recon Loss: 0.3106, Class Loss: 1.5046
#   Predicting classes: [0]
# Epoch 20/100:
#   Train Acc: 54.6%, Val Acc: 50.0%
#   Recon Loss: 0.1727, Class Loss: 1.0420
#   Predicting classes: [0]
# Epoch 30/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.1226, Class Loss: 1.0287
#   Predicting classes: [0]
# Epoch 40/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1095, Class Loss: 1.0108
#   Predicting classes: [0]
# Epoch 50/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.1183, Class Loss: 1.0062
#   Predicting classes: [0]
# Epoch 60/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.0872, Class Loss: 1.0027
#   Predicting classes: [0]
# Epoch 70/100:
#   Train Acc: 56.3%, Val Acc: 50.0%
#   Recon Loss: 0.0904, Class Loss: 0.9977
#   Predicting classes: [0]
# Epoch 80/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0856, Class Loss: 0.9906
#   Predicting classes: [0]
# Epoch 90/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1470, Class Loss: 0.9577
#   Predicting classes: [0]
# Epoch 100/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0799, Class Loss: 1.0070
#   Predicting classes: [0]
#
# Final Results:
#   Train Accuracy: 57.1%
#   Val Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/topological/attention_time_topological_8D_trial0.pth
#
# === Topological Model Trial 2/5 (time split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Acc: 34.0%, Val Acc: 25.0%
#   Recon Loss: 0.2783, Class Loss: 1.1576
#   Predicting classes: [1]
# Epoch 20/100:
#   Train Acc: 55.9%, Val Acc: 50.0%
#   Recon Loss: 0.1656, Class Loss: 1.0508
#   Predicting classes: [0]
# Epoch 30/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1123, Class Loss: 1.0067
#   Predicting classes: [0]
# Epoch 40/100:
#   Train Acc: 56.3%, Val Acc: 50.0%
#   Recon Loss: 0.1032, Class Loss: 0.9936
#   Predicting classes: [0]
# Epoch 50/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.0959, Class Loss: 1.0077
#   Predicting classes: [0]
# Epoch 60/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0868, Class Loss: 1.0145
#   Predicting classes: [0]
# Epoch 70/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0951, Class Loss: 1.0045
#   Predicting classes: [0]
# Epoch 80/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1231, Class Loss: 0.9843
#   Predicting classes: [0]
# Epoch 90/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1035, Class Loss: 1.0056
#   Predicting classes: [0]
# Epoch 100/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0984, Class Loss: 0.9905
#   Predicting classes: [0]
#
# Final Results:
#   Train Accuracy: 57.1%
#   Val Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/topological/attention_time_topological_8D_trial1.pth
#
# === Topological Model Trial 3/5 (time split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Acc: 46.6%, Val Acc: 25.0%
#   Recon Loss: 0.2588, Class Loss: 1.3656
#   Predicting classes: [0 2]
# Epoch 20/100:
#   Train Acc: 56.3%, Val Acc: 50.0%
#   Recon Loss: 0.1492, Class Loss: 1.0345
#   Predicting classes: [0]
# Epoch 30/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1181, Class Loss: 1.0127
#   Predicting classes: [0]
# Epoch 40/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1108, Class Loss: 0.9509
#   Predicting classes: [0]
# Epoch 50/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1110, Class Loss: 0.9855
#   Predicting classes: [0]
# Epoch 60/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1427, Class Loss: 0.9749
#   Predicting classes: [0]
# Epoch 70/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0962, Class Loss: 0.9858
#   Predicting classes: [0]
# Epoch 80/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1119, Class Loss: 1.0027
#   Predicting classes: [0]
# Epoch 90/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0983, Class Loss: 0.9842
#   Predicting classes: [0]
# Epoch 100/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0771, Class Loss: 0.9820
#   Predicting classes: [0]
#
# Final Results:
#   Train Accuracy: 57.1%
#   Val Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/topological/attention_time_topological_8D_trial2.pth
#
# === Topological Model Trial 4/5 (time split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Acc: 52.5%, Val Acc: 50.0%
#   Recon Loss: 0.2855, Class Loss: 1.1562
#   Predicting classes: [0]
# Epoch 20/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.2337, Class Loss: 1.0067
#   Predicting classes: [0]
# Epoch 30/100:
#   Train Acc: 55.9%, Val Acc: 50.0%
#   Recon Loss: 0.1309, Class Loss: 0.9942
#   Predicting classes: [0]
# Epoch 40/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1137, Class Loss: 0.9922
#   Predicting classes: [0]
# Epoch 50/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.1063, Class Loss: 1.0148
#   Predicting classes: [0]
# Epoch 60/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1099, Class Loss: 1.0005
#   Predicting classes: [0]
# Epoch 70/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0964, Class Loss: 0.9953
#   Predicting classes: [0]
# Epoch 80/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0928, Class Loss: 0.9983
#   Predicting classes: [0]
# Epoch 90/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.1003, Class Loss: 0.9924
#   Predicting classes: [0]
# Epoch 100/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0875, Class Loss: 0.9821
#   Predicting classes: [0]
#
# Final Results:
#   Train Accuracy: 57.1%
#   Val Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/topological/attention_time_topological_8D_trial3.pth
#
# === Topological Model Trial 5/5 (time split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Acc: 52.1%, Val Acc: 50.0%
#   Recon Loss: 0.2729, Class Loss: 1.1609
#   Predicting classes: [0]
# Epoch 20/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1523, Class Loss: 0.9684
#   Predicting classes: [0]
# Epoch 30/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.1319, Class Loss: 1.0036
#   Predicting classes: [0]
# Epoch 40/100:
#   Train Acc: 57.6%, Val Acc: 50.0%
#   Recon Loss: 0.1022, Class Loss: 0.9956
#   Predicting classes: [0]
# Epoch 50/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1369, Class Loss: 0.9895
#   Predicting classes: [0]
# Epoch 60/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0891, Class Loss: 0.9845
#   Predicting classes: [0]
# Epoch 70/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0917, Class Loss: 0.9662
#   Predicting classes: [0]
# Epoch 80/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1103, Class Loss: 1.0190
#   Predicting classes: [0]
# Epoch 90/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0920, Class Loss: 0.9657
#   Predicting classes: [0]
# Epoch 100/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0754, Class Loss: 0.9821
#   Predicting classes: [0]
#
# Final Results:
#   Train Accuracy: 57.1%
#   Val Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/topological/attention_time_topological_8D_trial4.pth
# Results saved to: /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/topological_results/topological_time_8d_cv_results.pkl
#
# === Topological Results (time split, 8D) ===
# Accuracy: 50.0% ± 0.0%
#
# --- LATENT DIMENSION: 48 ---
#
# SUBJECT SPLIT:
#
# === Topological Model Trial 1/5 (subject split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15040901', '14091701', '15111101', '15052902', '16100101', '14091102', '16100801', '16101401', '16100601', '16102002', '14092201', '15081202sub2', '15053001sub2', '15080601']
#   Test subjects (3): ['15053001sub1', '15012001', '14101601']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Acc: 41.3%, Val Acc: 29.6%
#   Recon Loss: 0.2794, Class Loss: 1.6044
#   Predicting classes: [0 1]
# Epoch 20/100:
#   Train Acc: 54.8%, Val Acc: 27.8%
#   Recon Loss: 0.1576, Class Loss: 1.0963
#   Predicting classes: [0 1]
# Epoch 30/100:
#   Train Acc: 55.6%, Val Acc: 25.9%
#   Recon Loss: 0.1584, Class Loss: 1.1185
#   Predicting classes: [0 1]
# Epoch 40/100:
#   Train Acc: 55.2%, Val Acc: 35.2%
#   Recon Loss: 0.2189, Class Loss: 1.0416
#   Predicting classes: [0 1]
# Epoch 50/100:
#   Train Acc: 55.2%, Val Acc: 37.0%
#   Recon Loss: 0.1142, Class Loss: 1.0920
#   Predicting classes: [0 1]
# Epoch 60/100:
#   Train Acc: 55.6%, Val Acc: 33.3%
#   Recon Loss: 0.1623, Class Loss: 1.0296
#   Predicting classes: [0 1]
# Epoch 70/100:
#   Train Acc: 55.6%, Val Acc: 35.2%
#   Recon Loss: 0.1072, Class Loss: 1.0250
#   Predicting classes: [0 1]
# Epoch 80/100:
#   Train Acc: 55.6%, Val Acc: 37.0%
#   Recon Loss: 0.0867, Class Loss: 0.9850
#   Predicting classes: [0 1]
# Epoch 90/100:
#   Train Acc: 55.6%, Val Acc: 51.9%
#   Recon Loss: 0.1873, Class Loss: 0.9983
#   Predicting classes: [0 1]
# Epoch 100/100:
#   Train Acc: 55.6%, Val Acc: 42.6%
#   Recon Loss: 0.0912, Class Loss: 1.0036
#   Predicting classes: [0 1]
#
# Final Results:
#   Train Accuracy: 55.6%
#   Val Accuracy: 42.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.55      0.57      0.56        30
#       Improv       0.26      0.50      0.34        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.43        54
#    macro avg       0.27      0.36      0.30        54
# weighted avg       0.36      0.43      0.39        54
#
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/topological/attention_subject_topological_48D_trial0.pth
#
# === Topological Model Trial 2/5 (subject split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['16101401', '15081202sub2', '14091701', '16102002', '15080601', '14091102', '15111101', '15053001sub2', '15040901', '14092201', '14101601', '15012001', '15053001sub1', '16100601']
#   Test subjects (3): ['16100101', '16100801', '15052902']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Acc: 31.7%, Val Acc: 42.6%
#   Recon Loss: 0.3118, Class Loss: 2.0794
#   Predicting classes: [0 2]
# Epoch 20/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.1629, Class Loss: 1.1188
#   Predicting classes: [0]
# Epoch 30/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.2658, Class Loss: 1.0618
#   Predicting classes: [0]
# Epoch 40/100:
#   Train Acc: 56.0%, Val Acc: 55.6%
#   Recon Loss: 0.1167, Class Loss: 1.0197
#   Predicting classes: [0]
# Epoch 50/100:
#   Train Acc: 56.0%, Val Acc: 55.6%
#   Recon Loss: 0.1060, Class Loss: 1.0243
#   Predicting classes: [0]
# Epoch 60/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.1381, Class Loss: 1.0075
#   Predicting classes: [0]
# Epoch 70/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1147, Class Loss: 1.0291
#   Predicting classes: [0]
# Epoch 80/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1340, Class Loss: 0.9970
#   Predicting classes: [0]
# Epoch 90/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0884, Class Loss: 1.0072
#   Predicting classes: [0]
# Epoch 100/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1090, Class Loss: 0.9940
#   Predicting classes: [0]
#
# Final Results:
#   Train Accuracy: 55.6%
#   Val Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/topological/attention_subject_topological_48D_trial1.pth
#
# === Topological Model Trial 3/5 (subject split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['14092201', '16100801', '15040901', '15080601', '16102002', '15052902', '15081202sub2', '16100601', '15053001sub1', '16101401', '14091701', '16100101', '15012001', '15053001sub2']
#   Test subjects (3): ['15111101', '14101601', '14091102']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Acc: 40.5%, Val Acc: 55.6%
#   Recon Loss: 0.2642, Class Loss: 3.5004
#   Predicting classes: [0]
# Epoch 20/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.3634, Class Loss: 1.0283
#   Predicting classes: [0]
# Epoch 30/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.1330, Class Loss: 1.0521
#   Predicting classes: [0]
# Epoch 40/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1104, Class Loss: 1.0495
#   Predicting classes: [0]
# Epoch 50/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0939, Class Loss: 1.0087
#   Predicting classes: [0]
# Epoch 60/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1147, Class Loss: 1.0042
#   Predicting classes: [0]
# Epoch 70/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0840, Class Loss: 0.9854
#   Predicting classes: [0]
# Epoch 80/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0803, Class Loss: 1.0047
#   Predicting classes: [0]
# Epoch 90/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0888, Class Loss: 0.9920
#   Predicting classes: [0]
# Epoch 100/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0694, Class Loss: 0.9948
#   Predicting classes: [0]
#
# Final Results:
#   Train Accuracy: 55.6%
#   Val Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/topological/attention_subject_topological_48D_trial2.pth
#
# === Topological Model Trial 4/5 (subject split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['14091102', '15080601', '16101401', '15012001', '16102002', '15052902', '16100601', '15040901', '14101601', '15053001sub1', '15081202sub2', '15053001sub2', '15111101', '14091701']
#   Test subjects (3): ['14092201', '16100801', '16100101']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Acc: 46.0%, Val Acc: 22.2%
#   Recon Loss: 0.2544, Class Loss: 1.5665
#   Predicting classes: [0 2]
# Epoch 20/100:
#   Train Acc: 44.4%, Val Acc: 48.1%
#   Recon Loss: 0.1537, Class Loss: 1.0947
#   Predicting classes: [0 2]
# Epoch 30/100:
#   Train Acc: 56.0%, Val Acc: 55.6%
#   Recon Loss: 0.1289, Class Loss: 1.0302
#   Predicting classes: [0]
# Epoch 40/100:
#   Train Acc: 54.8%, Val Acc: 51.9%
#   Recon Loss: 0.1081, Class Loss: 1.0313
#   Predicting classes: [0 2]
# Epoch 50/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1181, Class Loss: 1.0370
#   Predicting classes: [0]
# Epoch 60/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.1018, Class Loss: 1.0538
#   Predicting classes: [0]
# Epoch 70/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1498, Class Loss: 1.0128
#   Predicting classes: [0]
# Epoch 80/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1279, Class Loss: 1.0032
#   Predicting classes: [0]
# Epoch 90/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0879, Class Loss: 1.0059
#   Predicting classes: [0]
# Epoch 100/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0757, Class Loss: 0.9958
#   Predicting classes: [0]
#
# Final Results:
#   Train Accuracy: 55.6%
#   Val Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/topological/attention_subject_topological_48D_trial3.pth
#
# === Topological Model Trial 5/5 (subject split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15111101', '15081202sub2', '16100801', '15080601', '16100101', '15040901', '14091701', '15053001sub1', '14091102', '15053001sub2', '14092201', '16100601', '15052902', '14101601']
#   Test subjects (3): ['15012001', '16102002', '16101401']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Acc: 48.0%, Val Acc: 55.6%
#   Recon Loss: 0.2910, Class Loss: 2.1609
#   Predicting classes: [0]
# Epoch 20/100:
#   Train Acc: 54.4%, Val Acc: 55.6%
#   Recon Loss: 0.1720, Class Loss: 1.1440
#   Predicting classes: [0]
# Epoch 30/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1914, Class Loss: 1.0110
#   Predicting classes: [0]
# Epoch 40/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1704, Class Loss: 1.0070
#   Predicting classes: [0]
# Epoch 50/100:
#   Train Acc: 55.2%, Val Acc: 55.6%
#   Recon Loss: 0.1298, Class Loss: 1.1323
#   Predicting classes: [0]
# Epoch 60/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1101, Class Loss: 0.9917
#   Predicting classes: [0]
# Epoch 70/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.1027, Class Loss: 0.9945
#   Predicting classes: [0]
# Epoch 80/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0837, Class Loss: 0.9959
#   Predicting classes: [0]
# Epoch 90/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0786, Class Loss: 0.9949
#   Predicting classes: [0]
# Epoch 100/100:
#   Train Acc: 55.6%, Val Acc: 55.6%
#   Recon Loss: 0.0756, Class Loss: 0.9965
#   Predicting classes: [0]
#
# Final Results:
#   Train Accuracy: 55.6%
#   Val Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/topological/attention_subject_topological_48D_trial4.pth
# Results saved to: /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/topological_results/topological_subject_48d_cv_results.pkl
#
# === Topological Results (subject split, 48D) ===
# Accuracy: 53.0% ± 5.2%
#
# TIME SPLIT:
#
# === Topological Model Trial 1/5 (time split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Acc: 24.8%, Val Acc: 25.0%
#   Recon Loss: 0.3353, Class Loss: 1.5985
#   Predicting classes: [2]
# Epoch 20/100:
#   Train Acc: 57.1%, Val Acc: 39.7%
#   Recon Loss: 0.2175, Class Loss: 1.0575
#   Predicting classes: [0 2]
# Epoch 30/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.1424, Class Loss: 1.0542
#   Predicting classes: [0]
# Epoch 40/100:
#   Train Acc: 57.6%, Val Acc: 50.0%
#   Recon Loss: 0.1085, Class Loss: 1.0067
#   Predicting classes: [0]
# Epoch 50/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0970, Class Loss: 0.9948
#   Predicting classes: [0]
# Epoch 60/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1065, Class Loss: 1.0061
#   Predicting classes: [0]
# Epoch 70/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1193, Class Loss: 0.9749
#   Predicting classes: [0]
# Epoch 80/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0899, Class Loss: 0.9907
#   Predicting classes: [0]
# Epoch 90/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.0792, Class Loss: 0.9926
#   Predicting classes: [0]
# Epoch 100/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0771, Class Loss: 0.9777
#   Predicting classes: [0]
#
# Final Results:
#   Train Accuracy: 57.1%
#   Val Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/topological/attention_time_topological_48D_trial0.pth
#
# === Topological Model Trial 2/5 (time split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Acc: 44.5%, Val Acc: 50.0%
#   Recon Loss: 0.3057, Class Loss: 5.5247
#   Predicting classes: [0]
# Epoch 20/100:
#   Train Acc: 56.3%, Val Acc: 50.0%
#   Recon Loss: 0.1999, Class Loss: 1.0599
#   Predicting classes: [0]
# Epoch 30/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.1197, Class Loss: 1.0494
#   Predicting classes: [0]
# Epoch 40/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1295, Class Loss: 0.9997
#   Predicting classes: [0]
# Epoch 50/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1419, Class Loss: 1.0080
#   Predicting classes: [0]
# Epoch 60/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.1020, Class Loss: 1.0004
#   Predicting classes: [0]
# Epoch 70/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1431, Class Loss: 0.9953
#   Predicting classes: [0]
# Epoch 80/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1424, Class Loss: 0.9823
#   Predicting classes: [0]
# Epoch 90/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1063, Class Loss: 0.9970
#   Predicting classes: [0]
# Epoch 100/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.0986, Class Loss: 0.9807
#   Predicting classes: [0]
#
# Final Results:
#   Train Accuracy: 56.7%
#   Val Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/topological/attention_time_topological_48D_trial1.pth
#
# === Topological Model Trial 3/5 (time split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Acc: 52.9%, Val Acc: 50.0%
#   Recon Loss: 0.3032, Class Loss: 1.6367
#   Predicting classes: [0]
# Epoch 20/100:
#   Train Acc: 56.3%, Val Acc: 50.0%
#   Recon Loss: 0.2779, Class Loss: 1.0228
#   Predicting classes: [0]
# Epoch 30/100:
#   Train Acc: 55.9%, Val Acc: 50.0%
#   Recon Loss: 0.1540, Class Loss: 1.0363
#   Predicting classes: [0]
# Epoch 40/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1276, Class Loss: 1.0097
#   Predicting classes: [0]
# Epoch 50/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1427, Class Loss: 1.0005
#   Predicting classes: [0]
# Epoch 60/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.1986, Class Loss: 1.0079
#   Predicting classes: [0]
# Epoch 70/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1422, Class Loss: 1.0001
#   Predicting classes: [0]
# Epoch 80/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1035, Class Loss: 0.9937
#   Predicting classes: [0]
# Epoch 90/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.2399, Class Loss: 0.9797
#   Predicting classes: [0]
# Epoch 100/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1111, Class Loss: 0.9876
#   Predicting classes: [0]
#
# Final Results:
#   Train Accuracy: 57.1%
#   Val Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/topological/attention_time_topological_48D_trial2.pth
#
# === Topological Model Trial 4/5 (time split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Acc: 41.6%, Val Acc: 20.6%
#   Recon Loss: 0.3273, Class Loss: 2.4601
#   Predicting classes: [0 2]
# Epoch 20/100:
#   Train Acc: 58.0%, Val Acc: 48.5%
#   Recon Loss: 0.2616, Class Loss: 1.0477
#   Predicting classes: [0 2]
# Epoch 30/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1644, Class Loss: 1.0175
#   Predicting classes: [0]
# Epoch 40/100:
#   Train Acc: 57.6%, Val Acc: 50.0%
#   Recon Loss: 0.1252, Class Loss: 1.0025
#   Predicting classes: [0]
# Epoch 50/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1081, Class Loss: 0.9846
#   Predicting classes: [0]
# Epoch 60/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1004, Class Loss: 1.0271
#   Predicting classes: [0]
# Epoch 70/100:
#   Train Acc: 57.6%, Val Acc: 50.0%
#   Recon Loss: 0.0915, Class Loss: 0.9773
#   Predicting classes: [0]
# Epoch 80/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0911, Class Loss: 0.9771
#   Predicting classes: [0]
# Epoch 90/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0894, Class Loss: 0.9857
#   Predicting classes: [0]
# Epoch 100/100:
#   Train Acc: 56.7%, Val Acc: 50.0%
#   Recon Loss: 0.0881, Class Loss: 0.9697
#   Predicting classes: [0]
#
# Final Results:
#   Train Accuracy: 56.7%
#   Val Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/topological/attention_time_topological_48D_trial3.pth
#
# === Topological Model Trial 5/5 (time split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Acc: 53.8%, Val Acc: 50.0%
#   Recon Loss: 0.3107, Class Loss: 1.3933
#   Predicting classes: [0]
# Epoch 20/100:
#   Train Acc: 56.3%, Val Acc: 50.0%
#   Recon Loss: 0.1842, Class Loss: 1.0819
#   Predicting classes: [0]
# Epoch 30/100:
#   Train Acc: 57.6%, Val Acc: 50.0%
#   Recon Loss: 0.1532, Class Loss: 1.0150
#   Predicting classes: [0]
# Epoch 40/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1422, Class Loss: 0.9839
#   Predicting classes: [0]
# Epoch 50/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0984, Class Loss: 0.9900
#   Predicting classes: [0]
# Epoch 60/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.1081, Class Loss: 0.9728
#   Predicting classes: [0]
# Epoch 70/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0873, Class Loss: 1.0246
#   Predicting classes: [0]
# Epoch 80/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0755, Class Loss: 0.9736
#   Predicting classes: [0]
# Epoch 90/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0732, Class Loss: 0.9800
#   Predicting classes: [0]
# Epoch 100/100:
#   Train Acc: 57.1%, Val Acc: 50.0%
#   Recon Loss: 0.0795, Class Loss: 0.9753
#   Predicting classes: [0]
#
# Final Results:
#   Train Accuracy: 57.1%
#   Val Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/topological/attention_time_topological_48D_trial4.pth
# Results saved to: /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/topological_results/topological_time_48d_cv_results.pkl
#
# === Topological Results (time split, 48D) ===
# Accuracy: 50.0% ± 0.0%
#
# ✓ Results saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/topological_results/topological_cv_results.pkl
#
# === CROSS-VALIDATION SUMMARY ===
#
# 8D Latent Space:
#   Subject: 55.6% ± 0.0%
#   Time: 50.0% ± 0.0%
#
# 48D Latent Space:
#   Subject: 53.0% ± 5.2%
#   Time: 50.0% ± 0.0%
