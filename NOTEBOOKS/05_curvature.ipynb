# %%
### SETUP ###
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import pickle
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings('ignore')
from SCRIPTS.config import *
from SCRIPTS.dataprep import prepare_interval_data
from SCRIPTS.curvature_models import CurvatureModel
from SCRIPTS.curvature_training import train_curvature_model, evaluate_model, IntervalDataset
from SCRIPTS.cross_validation_experiments import run_curvature_cross_validation

# Visualization setup
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("husl")

# Set random seed
np.random.seed(42)
torch.manual_seed(42)

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
print(f"Data path: {COMBINED_SCATTERING}")
print(f"Results path: {CURVATURE_RESULTS_DIR}")
# Out:
# Using device: cpu
# Data path: /Users/judesack/Neurospectrum_Creativity/DATA/SCATTERING_COEFFICIENTS/combined_scattering_data.csv
# Results path: /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/curvature_results

# %%
### CONFIGURATION ###

# Train curvature models? T/F
TRAIN_CURVATURE = False

# Run cross-validation? T/F
RUN_CROSS_VALIDATION = True

# Number of CV trials (set to 5)
CV_TRIALS = 5

# Latent dimensions to test
LATENT_DIMS = [8, 48]

# %%
### LOAD INTERVAL DATA ###

print("\n=== LOADING INTERVAL DATA ===")
train_loader_subj, test_loader_subj, info_subj = prepare_interval_data(
    scattering_data_path=COMBINED_SCATTERING,
    split_type='subject',
    batch_size=16,
    random_state=42
)

train_loader_time, test_loader_time, info_time = prepare_interval_data(
    scattering_data_path=COMBINED_SCATTERING,
    split_type='time',
    batch_size=16,
    random_state=42
)

print(f"\nSubject split: {info_subj['n_train']} train, {info_subj['n_test']} test")
print(f"Time split: {info_time['n_train']} train, {info_time['n_test']} test")
# Out:
# === LOADING INTERVAL DATA ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['14091102', '14091701', '15053001sub2', '16100801', '15012001', '15040901', '16101401', '15111101', '15081202sub2', '15080601', '16100101', '15052902', '16100601', '15053001sub1']
#   Test subjects (3): ['14092201', '16102002', '14101601']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
#
# Subject split: 252 train, 54 test
# Time split: 238 train, 68 test

# %%
### TRAIN CURVATURE MODELS ###

if TRAIN_CURVATURE:
    print("\n=== TRAINING CURVATURE MODELS ===")
    
    results = {}
    
    for latent_dim in LATENT_DIMS:
        print(f"\n--- Latent Dimension: {latent_dim} ---")
        results[latent_dim] = {}
        
        print("\nSUBJECT WITHHOLDING:")
        
        # Convert DataLoader to intervals for curvature training
        train_intervals = []
        for batch in train_loader_subj:
            features, labels, subjects, intervals = batch
            for i in range(len(features)):
                train_intervals.append((
                    features[i].numpy(),
                    labels[i].item(),
                    subjects[i],
                    intervals[i]
                ))
        
        test_intervals = []
        for batch in test_loader_subj:
            features, labels, subjects, intervals = batch
            for i in range(len(features)):
                test_intervals.append((
                    features[i].numpy(),
                    labels[i].item(),
                    subjects[i],
                    intervals[i]
                ))
        
        model, history = train_curvature_model(
            train_intervals=train_intervals,
            test_intervals=test_intervals,
            latent_dim=latent_dim,
            num_epochs=DEFAULT_EPOCHS,
            batch_size=16,
            learning_rate=DEFAULT_LEARNING_RATE,
            recon_weight = LOSS_WEIGHTS['reconstruction'],
            device=device
        )
        
        results[latent_dim]['subject'] = {
            'accuracy': history['test_acc'][-1],
            'history': history,
            'model_state': model.state_dict()
        }
        
        save_path = CURVATURE_RESULTS_DIR / f'curvature_subject_{latent_dim}d.pth'
        torch.save({
            'model_state_dict': model.state_dict(),
            'history': history,
            'latent_dim': latent_dim,
            'split_type': 'subject'
        }, save_path)
        print(f"✓ Model saved to {save_path}")
        
        print("\nTIME WITHHOLDING:")
        
        train_intervals = []
        for batch in train_loader_time:
            features, labels, subjects, intervals = batch
            for i in range(len(features)):
                train_intervals.append((
                    features[i].numpy(),
                    labels[i].item(),
                    subjects[i],
                    intervals[i]
                ))
        
        test_intervals = []
        for batch in test_loader_time:
            features, labels, subjects, intervals = batch
            for i in range(len(features)):
                test_intervals.append((
                    features[i].numpy(),
                    labels[i].item(),
                    subjects[i],
                    intervals[i]
                ))
        
        model, history = train_curvature_model(
            train_intervals=train_intervals,
            test_intervals=test_intervals,
            latent_dim=latent_dim,
            num_epochs=DEFAULT_EPOCHS,
            batch_size=16,
            learning_rate=DEFAULT_LEARNING_RATE,
            recon_weight = LOSS_WEIGHTS['reconstruction'],
            device=device
        )
        
        results[latent_dim]['time'] = {
            'accuracy': history['test_acc'][-1],
            'history': history,
            'model_state': model.state_dict()
        }
        
        save_path = CURVATURE_RESULTS_DIR / f'curvature_time_{latent_dim}d.pth'
        torch.save({
            'model_state_dict': model.state_dict(),
            'history': history,
            'latent_dim': latent_dim,
            'split_type': 'time'
        }, save_path)
        print(f"✓ Model saved to {save_path}")
    
    print("\n=== CURVATURE MODEL RESULTS ===")
    for latent_dim in LATENT_DIMS:
        print(f"\n{latent_dim}D Latent Space:")
        print(f"  Subject: {results[latent_dim]['subject']['accuracy']:.1f}%")
        print(f"  Time: {results[latent_dim]['time']['accuracy']:.1f}%")

else:
    print("✓ Skipping curvature model training")
# Out:
# ✓ Skipping curvature model training

# %%
### CROSS-VALIDATION ###

if RUN_CROSS_VALIDATION:
    print(f"\n=== CROSS-VALIDATION EXPERIMENTS ({CV_TRIALS} trials) ===")
    
    cv_results = {}
    
    for latent_dim in LATENT_DIMS:
        print(f"\n--- LATENT DIMENSION: {latent_dim} ---")
        cv_results[latent_dim] = {}
        
        for split_type in ['subject', 'time']:
            print(f"\n{split_type.upper()} SPLIT:")
            cv_results[latent_dim][split_type] = run_curvature_cross_validation(
                data_path=COMBINED_SCATTERING,
                split_type=split_type,
                latent_dim=latent_dim,
                num_trials=CV_TRIALS,
                num_epochs=DEFAULT_EPOCHS
            )
    
    # Save results
    save_path = CURVATURE_RESULTS_DIR / 'curvature_cv_results.pkl'
    with open(save_path, 'wb') as f:
        pickle.dump(cv_results, f)
    print(f"\n✓ Results saved to {save_path}")
    
    # Display summary
    print("\n=== CROSS-VALIDATION SUMMARY ===")
    for latent_dim in LATENT_DIMS:
        print(f"\n{latent_dim}D Latent Space:")
        print(f"  Subject: {cv_results[latent_dim]['subject']['mean_accuracy']:.1f}% ± {cv_results[latent_dim]['subject']['std_accuracy']:.1f}%")
        print(f"  Time: {cv_results[latent_dim]['time']['mean_accuracy']:.1f}% ± {cv_results[latent_dim]['time']['std_accuracy']:.1f}%")

else:
    # Load existing results
    cv_file = CURVATURE_RESULTS_DIR / 'curvature_cv_results.pkl'
    
    if cv_file.exists():
        with open(cv_file, 'rb') as f:
            cv_results = pickle.load(f)
        
        print("✓ Loaded existing cross-validation results")
        
        print("\n=== CROSS-VALIDATION SUMMARY ===")
        for latent_dim in LATENT_DIMS:
            if latent_dim in cv_results:
                print(f"\n{latent_dim}D Latent Space:")
                print(f"  Subject: {cv_results[latent_dim]['subject']['mean_accuracy']:.1f}% ± {cv_results[latent_dim]['subject']['std_accuracy']:.1f}%")
                print(f"  Time: {cv_results[latent_dim]['time']['mean_accuracy']:.1f}% ± {cv_results[latent_dim]['time']['std_accuracy']:.1f}%")
    else:
        print("✓ No existing cross-validation results found")
# Out:
# === CROSS-VALIDATION EXPERIMENTS (5 trials) ===
#
# --- LATENT DIMENSION: 8 ---
#
# SUBJECT SPLIT:
#
# === Curvature Model Trial 1/5 (subject split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['14091102', '14091701', '15053001sub2', '16100801', '15012001', '15040901', '16101401', '15111101', '15081202sub2', '15080601', '16100101', '15052902', '16100601', '15053001sub1']
#   Test subjects (3): ['14092201', '16102002', '14101601']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Loss: 1.4993 (Class: 1.0368, Recon: 0.6602)
#   Train Acc: 55.42%, Test Acc: 55.56%
#   Curvature: mean=7.6741, std=15.7811
# Epoch 20/100:
#   Train Loss: 1.0447 (Class: 1.0139, Recon: 0.5364)
#   Train Acc: 55.42%, Test Acc: 55.56%
#   Curvature: mean=4.6116, std=11.0097
# Epoch 30/100:
#   Train Loss: 0.9030 (Class: 0.9908, Recon: 0.4554)
#   Train Acc: 53.75%, Test Acc: 22.22%
#   Curvature: mean=3.0267, std=8.2937
# Epoch 40/100:
#   Train Loss: 0.8311 (Class: 0.9561, Recon: 0.3986)
#   Train Acc: 58.75%, Test Acc: 55.56%
#   Curvature: mean=2.2815, std=5.1787
# Epoch 50/100:
#   Train Loss: 0.7900 (Class: 0.9445, Recon: 0.3667)
#   Train Acc: 57.92%, Test Acc: 55.56%
#   Curvature: mean=1.7560, std=3.3099
# Epoch 60/100:
#   Train Loss: 0.7047 (Class: 0.8614, Recon: 0.3070)
#   Train Acc: 60.83%, Test Acc: 46.30%
#   Curvature: mean=1.4398, std=2.6895
# Epoch 70/100:
#   Train Loss: 0.6731 (Class: 0.8215, Recon: 0.2937)
#   Train Acc: 64.58%, Test Acc: 55.56%
#   Curvature: mean=1.2657, std=2.4680
# Epoch 80/100:
#   Train Loss: 0.6321 (Class: 0.7719, Recon: 0.2731)
#   Train Acc: 65.42%, Test Acc: 55.56%
#   Curvature: mean=1.1823, std=2.0548
# Epoch 90/100:
#   Train Loss: 0.6111 (Class: 0.7396, Recon: 0.2851)
#   Train Acc: 67.08%, Test Acc: 55.56%
#   Curvature: mean=1.1668, std=2.1148
# Epoch 100/100:
#   Train Loss: 0.6061 (Class: 0.7470, Recon: 0.2659)
#   Train Acc: 66.67%, Test Acc: 55.56%
#   Curvature: mean=1.1308, std=1.9994
#
# Final Results:
#   Train Accuracy: 66.7%
#   Test Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
#   DEBUG - curvature attention weights:
#     Range: [0.0149, 1.0979]
#     Mean: 0.4201, Std: 0.2731
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/curvature/attention_subject_curvature_8D_trial0.pth
#
# === Curvature Model Trial 2/5 (subject split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15111101', '15052902', '14091701', '15080601', '15053001sub1', '15040901', '15053001sub2', '16100601', '14091102', '16100101', '14101601', '16102002', '14092201', '15081202sub2']
#   Test subjects (3): ['15012001', '16101401', '16100801']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Loss: 1.4803 (Class: 1.0459, Recon: 0.6718)
#   Train Acc: 54.17%, Test Acc: 50.00%
#   Curvature: mean=6.3690, std=15.3170
# Epoch 20/100:
#   Train Loss: 1.0178 (Class: 1.0019, Recon: 0.5064)
#   Train Acc: 56.25%, Test Acc: 55.56%
#   Curvature: mean=3.7501, std=7.7210
# Epoch 30/100:
#   Train Loss: 0.9080 (Class: 1.0188, Recon: 0.4369)
#   Train Acc: 54.58%, Test Acc: 53.70%
#   Curvature: mean=2.6890, std=6.4015
# Epoch 40/100:
#   Train Loss: 0.8144 (Class: 0.9453, Recon: 0.3656)
#   Train Acc: 57.92%, Test Acc: 55.56%
#   Curvature: mean=2.3425, std=5.3779
# Epoch 50/100:
#   Train Loss: 0.7641 (Class: 0.9104, Recon: 0.3339)
#   Train Acc: 60.83%, Test Acc: 55.56%
#   Curvature: mean=1.9942, std=4.4226
# Epoch 60/100:
#   Train Loss: 0.7345 (Class: 0.8840, Recon: 0.3274)
#   Train Acc: 59.17%, Test Acc: 55.56%
#   Curvature: mean=1.9724, std=4.4083
# Epoch 70/100:
#   Train Loss: 0.7197 (Class: 0.8897, Recon: 0.2937)
#   Train Acc: 61.25%, Test Acc: 55.56%
#   Curvature: mean=1.8435, std=3.6699
# Epoch 80/100:
#   Train Loss: 0.6816 (Class: 0.8348, Recon: 0.2871)
#   Train Acc: 64.17%, Test Acc: 55.56%
#   Curvature: mean=1.8057, std=3.5399
# Epoch 90/100:
#   Train Loss: 0.6799 (Class: 0.8297, Recon: 0.2939)
#   Train Acc: 64.58%, Test Acc: 55.56%
#   Curvature: mean=1.8043, std=3.6187
# Epoch 100/100:
#   Train Loss: 0.7195 (Class: 0.8839, Recon: 0.3082)
#   Train Acc: 60.83%, Test Acc: 55.56%
#   Curvature: mean=1.8351, std=3.7805
#
# Final Results:
#   Train Accuracy: 60.8%
#   Test Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
#   DEBUG - curvature attention weights:
#     Range: [0.0001, 1.2241]
#     Mean: 0.3470, Std: 0.2986
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/curvature/attention_subject_curvature_8D_trial1.pth
#
# === Curvature Model Trial 3/5 (subject split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['16100101', '16101401', '14091102', '15053001sub1', '15080601', '16100801', '15052902', '15081202sub2', '14092201', '15111101', '14091701', '15012001', '16102002', '16100601']
#   Test subjects (3): ['15053001sub2', '14101601', '15040901']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Loss: 1.4344 (Class: 1.0428, Recon: 0.6277)
#   Train Acc: 52.08%, Test Acc: 55.56%
#   Curvature: mean=6.9617, std=13.8248
# Epoch 20/100:
#   Train Loss: 1.0033 (Class: 0.9877, Recon: 0.4888)
#   Train Acc: 55.42%, Test Acc: 55.56%
#   Curvature: mean=4.1381, std=7.5712
# Epoch 30/100:
#   Train Loss: 0.8848 (Class: 1.0115, Recon: 0.3734)
#   Train Acc: 56.67%, Test Acc: 53.70%
#   Curvature: mean=3.1339, std=5.2613
# Epoch 40/100:
#   Train Loss: 0.8311 (Class: 0.9861, Recon: 0.3625)
#   Train Acc: 55.42%, Test Acc: 22.22%
#   Curvature: mean=2.6816, std=5.4496
# Epoch 50/100:
#   Train Loss: 0.7709 (Class: 0.9514, Recon: 0.2889)
#   Train Acc: 56.67%, Test Acc: 22.22%
#   Curvature: mean=2.4914, std=4.5710
# Epoch 60/100:
#   Train Loss: 0.7905 (Class: 0.9638, Recon: 0.3369)
#   Train Acc: 54.58%, Test Acc: 22.22%
#   Curvature: mean=2.4323, std=4.4425
# Epoch 70/100:
#   Train Loss: 0.7629 (Class: 0.9384, Recon: 0.3080)
#   Train Acc: 53.75%, Test Acc: 22.22%
#   Curvature: mean=2.4493, std=4.5045
# Epoch 80/100:
#   Train Loss: 0.7718 (Class: 0.9650, Recon: 0.2947)
#   Train Acc: 57.50%, Test Acc: 22.22%
#   Curvature: mean=2.4528, std=4.1983
# Epoch 90/100:
#   Train Loss: 0.7719 (Class: 0.9555, Recon: 0.3043)
#   Train Acc: 55.83%, Test Acc: 22.22%
#   Curvature: mean=2.4602, std=4.2671
# Epoch 100/100:
#   Train Loss: 0.7490 (Class: 0.9279, Recon: 0.2929)
#   Train Acc: 57.92%, Test Acc: 22.22%
#   Curvature: mean=2.4523, std=4.2529
#
# Final Results:
#   Train Accuracy: 57.9%
#   Test Accuracy: 22.2%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.00      0.00      0.00        30
#       Improv       0.22      1.00      0.36        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.22        54
#    macro avg       0.07      0.33      0.12        54
# weighted avg       0.05      0.22      0.08        54
#
#   DEBUG - curvature attention weights:
#     Range: [0.0195, 1.4922]
#     Mean: 0.4477, Std: 0.3340
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/curvature/attention_subject_curvature_8D_trial2.pth
#
# === Curvature Model Trial 4/5 (subject split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15040901', '15053001sub1', '15111101', '16102002', '15080601', '16100801', '15081202sub2', '14091102', '14101601', '14092201', '15052902', '16100601', '15053001sub2', '14091701']
#   Test subjects (3): ['16100101', '16101401', '15012001']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Loss: 1.5139 (Class: 1.0222, Recon: 0.6929)
#   Train Acc: 56.25%, Test Acc: 57.41%
#   Curvature: mean=9.3826, std=20.1061
# Epoch 20/100:
#   Train Loss: 1.0322 (Class: 1.0121, Recon: 0.5454)
#   Train Acc: 55.00%, Test Acc: 55.56%
#   Curvature: mean=6.0486, std=15.7815
# Epoch 30/100:
#   Train Loss: 0.8913 (Class: 1.0111, Recon: 0.4016)
#   Train Acc: 55.83%, Test Acc: 55.56%
#   Curvature: mean=3.4686, std=9.9555
# Epoch 40/100:
#   Train Loss: 0.8217 (Class: 0.9802, Recon: 0.3491)
#   Train Acc: 56.67%, Test Acc: 55.56%
#   Curvature: mean=2.8564, std=6.0250
# Epoch 50/100:
#   Train Loss: 0.7765 (Class: 0.9631, Recon: 0.3045)
#   Train Acc: 55.00%, Test Acc: 55.56%
#   Curvature: mean=2.5091, std=6.2555
# Epoch 60/100:
#   Train Loss: 0.7284 (Class: 0.9036, Recon: 0.3032)
#   Train Acc: 61.67%, Test Acc: 55.56%
#   Curvature: mean=1.9620, std=4.1756
# Epoch 70/100:
#   Train Loss: 0.7085 (Class: 0.8892, Recon: 0.2831)
#   Train Acc: 62.08%, Test Acc: 55.56%
#   Curvature: mean=1.9520, std=4.6903
# Epoch 80/100:
#   Train Loss: 0.7321 (Class: 0.9165, Recon: 0.3050)
#   Train Acc: 57.50%, Test Acc: 55.56%
#   Curvature: mean=1.9854, std=4.9337
# Epoch 90/100:
#   Train Loss: 0.7175 (Class: 0.9053, Recon: 0.2882)
#   Train Acc: 58.75%, Test Acc: 55.56%
#   Curvature: mean=1.9369, std=4.5378
# Epoch 100/100:
#   Train Loss: 0.7095 (Class: 0.9048, Recon: 0.2641)
#   Train Acc: 60.42%, Test Acc: 55.56%
#   Curvature: mean=1.9090, std=4.6343
#
# Final Results:
#   Train Accuracy: 60.4%
#   Test Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
#   DEBUG - curvature attention weights:
#     Range: [0.0277, 0.9397]
#     Mean: 0.3263, Std: 0.2160
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/curvature/attention_subject_curvature_8D_trial3.pth
#
# === Curvature Model Trial 5/5 (subject split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15053001sub2', '15052902', '16101401', '15053001sub1', '15012001', '14091102', '14091701', '14092201', '15040901', '16100601', '16100101', '15081202sub2', '16100801', '14101601']
#   Test subjects (3): ['16102002', '15080601', '15111101']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Loss: 1.4552 (Class: 1.0250, Recon: 0.6810)
#   Train Acc: 56.67%, Test Acc: 55.56%
#   Curvature: mean=8.0560, std=18.5209
# Epoch 20/100:
#   Train Loss: 1.0405 (Class: 1.0201, Recon: 0.5496)
#   Train Acc: 54.58%, Test Acc: 55.56%
#   Curvature: mean=4.5002, std=11.4370
# Epoch 30/100:
#   Train Loss: 0.9263 (Class: 0.9947, Recon: 0.4916)
#   Train Acc: 55.42%, Test Acc: 55.56%
#   Curvature: mean=3.3285, std=6.1637
# Epoch 40/100:
#   Train Loss: 0.8596 (Class: 0.9737, Recon: 0.4094)
#   Train Acc: 57.50%, Test Acc: 55.56%
#   Curvature: mean=2.5841, std=5.1049
# Epoch 50/100:
#   Train Loss: 0.8139 (Class: 0.9424, Recon: 0.3866)
#   Train Acc: 61.25%, Test Acc: 55.56%
#   Curvature: mean=2.3064, std=4.6747
# Epoch 60/100:
#   Train Loss: 0.7565 (Class: 0.8748, Recon: 0.3573)
#   Train Acc: 63.33%, Test Acc: 55.56%
#   Curvature: mean=2.0741, std=3.6655
# Epoch 70/100:
#   Train Loss: 0.7383 (Class: 0.8520, Recon: 0.3596)
#   Train Acc: 65.00%, Test Acc: 55.56%
#   Curvature: mean=2.1307, std=3.8512
# Epoch 80/100:
#   Train Loss: 0.7503 (Class: 0.8638, Recon: 0.3732)
#   Train Acc: 63.33%, Test Acc: 55.56%
#   Curvature: mean=2.0814, std=3.8031
# Epoch 90/100:
#   Train Loss: 0.7504 (Class: 0.8765, Recon: 0.3553)
#   Train Acc: 61.67%, Test Acc: 55.56%
#   Curvature: mean=2.0879, std=3.8112
# Epoch 100/100:
#   Train Loss: 0.7202 (Class: 0.8498, Recon: 0.3310)
#   Train Acc: 63.33%, Test Acc: 55.56%
#   Curvature: mean=2.0562, std=3.7415
#
# Final Results:
#   Train Accuracy: 63.3%
#   Test Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
#   DEBUG - curvature attention weights:
#     Range: [0.0398, 1.5195]
#     Mean: 0.4656, Std: 0.3128
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/curvature/attention_subject_curvature_8D_trial4.pth
# Results saved to: /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/curvature_results/curvature_subject_8d_cv_results.pkl
#
# === Curvature Results (subject split, 8D) ===
# Accuracy: 48.9% ± 13.3%
#
# TIME SPLIT:
#
# === Curvature Model Trial 1/5 (time split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Loss: 1.5191 (Class: 1.0179, Recon: 0.6917)
#   Train Acc: 55.80%, Test Acc: 50.00%
#   Curvature: mean=8.6993, std=19.8046
# Epoch 20/100:
#   Train Loss: 1.0321 (Class: 0.9798, Recon: 0.5374)
#   Train Acc: 57.14%, Test Acc: 50.00%
#   Curvature: mean=5.2803, std=11.4551
# Epoch 30/100:
#   Train Loss: 0.9228 (Class: 0.9992, Recon: 0.4659)
#   Train Acc: 57.59%, Test Acc: 50.00%
#   Curvature: mean=4.1136, std=8.7717
# Epoch 40/100:
#   Train Loss: 0.8408 (Class: 0.9671, Recon: 0.3870)
#   Train Acc: 57.14%, Test Acc: 50.00%
#   Curvature: mean=2.8878, std=6.0046
# Epoch 50/100:
#   Train Loss: 0.7778 (Class: 0.9025, Recon: 0.3698)
#   Train Acc: 60.27%, Test Acc: 50.00%
#   Curvature: mean=2.0668, std=4.3286
# Epoch 60/100:
#   Train Loss: 0.7176 (Class: 0.8422, Recon: 0.3445)
#   Train Acc: 64.73%, Test Acc: 50.00%
#   Curvature: mean=1.7814, std=4.0648
# Epoch 70/100:
#   Train Loss: 0.6404 (Class: 0.7584, Recon: 0.3001)
#   Train Acc: 67.86%, Test Acc: 50.00%
#   Curvature: mean=1.5179, std=3.5039
# Epoch 80/100:
#   Train Loss: 0.6087 (Class: 0.7189, Recon: 0.2906)
#   Train Acc: 69.64%, Test Acc: 47.06%
#   Curvature: mean=1.3528, std=2.8588
# Epoch 90/100:
#   Train Loss: 0.5938 (Class: 0.7174, Recon: 0.2752)
#   Train Acc: 68.75%, Test Acc: 47.06%
#   Curvature: mean=1.3172, std=2.6584
# Epoch 100/100:
#   Train Loss: 0.5672 (Class: 0.6742, Recon: 0.2768)
#   Train Acc: 69.64%, Test Acc: 48.53%
#   Curvature: mean=1.3131, std=2.6372
#
# Final Results:
#   Train Accuracy: 69.6%
#   Test Accuracy: 48.5%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.49      0.97      0.65        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.49        68
#    macro avg       0.16      0.32      0.22        68
# weighted avg       0.25      0.49      0.33        68
#
#   DEBUG - curvature attention weights:
#     Range: [0.0116, 1.4926]
#     Mean: 0.3376, Std: 0.2682
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/curvature/attention_time_curvature_8D_trial0.pth
#
# === Curvature Model Trial 2/5 (time split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Loss: 1.5342 (Class: 1.0471, Recon: 0.6632)
#   Train Acc: 53.57%, Test Acc: 50.00%
#   Curvature: mean=8.5326, std=17.0051
# Epoch 20/100:
#   Train Loss: 1.0131 (Class: 0.9739, Recon: 0.5098)
#   Train Acc: 58.04%, Test Acc: 50.00%
#   Curvature: mean=5.5370, std=11.7783
# Epoch 30/100:
#   Train Loss: 0.9398 (Class: 1.0100, Recon: 0.4587)
#   Train Acc: 57.59%, Test Acc: 50.00%
#   Curvature: mean=3.8762, std=8.1644
# Epoch 40/100:
#   Train Loss: 0.8281 (Class: 0.9612, Recon: 0.3700)
#   Train Acc: 58.04%, Test Acc: 50.00%
#   Curvature: mean=2.8120, std=6.3867
# Epoch 50/100:
#   Train Loss: 0.7773 (Class: 0.9234, Recon: 0.3523)
#   Train Acc: 58.04%, Test Acc: 50.00%
#   Curvature: mean=2.2645, std=4.2736
# Epoch 60/100:
#   Train Loss: 0.6973 (Class: 0.8458, Recon: 0.3041)
#   Train Acc: 62.95%, Test Acc: 50.00%
#   Curvature: mean=1.9545, std=4.3870
# Epoch 70/100:
#   Train Loss: 0.6275 (Class: 0.7448, Recon: 0.2943)
#   Train Acc: 68.30%, Test Acc: 50.00%
#   Curvature: mean=1.8677, std=4.0063
# Epoch 80/100:
#   Train Loss: 0.6391 (Class: 0.7802, Recon: 0.2760)
#   Train Acc: 66.96%, Test Acc: 50.00%
#   Curvature: mean=1.8114, std=3.7977
# Epoch 90/100:
#   Train Loss: 0.6294 (Class: 0.7599, Recon: 0.2719)
#   Train Acc: 66.96%, Test Acc: 50.00%
#   Curvature: mean=1.7877, std=3.8577
# Epoch 100/100:
#   Train Loss: 0.6341 (Class: 0.7656, Recon: 0.2823)
#   Train Acc: 68.30%, Test Acc: 50.00%
#   Curvature: mean=1.8181, std=4.0295
#
# Final Results:
#   Train Accuracy: 68.3%
#   Test Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
#   DEBUG - curvature attention weights:
#     Range: [0.0328, 1.1308]
#     Mean: 0.4411, Std: 0.2864
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/curvature/attention_time_curvature_8D_trial1.pth
#
# === Curvature Model Trial 3/5 (time split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Loss: 1.5617 (Class: 1.0363, Recon: 0.7247)
#   Train Acc: 56.25%, Test Acc: 50.00%
#   Curvature: mean=9.3948, std=17.5924
# Epoch 20/100:
#   Train Loss: 1.0257 (Class: 0.9965, Recon: 0.5118)
#   Train Acc: 57.59%, Test Acc: 50.00%
#   Curvature: mean=5.6708, std=11.0253
# Epoch 30/100:
#   Train Loss: 0.8925 (Class: 0.9608, Recon: 0.4443)
#   Train Acc: 57.14%, Test Acc: 50.00%
#   Curvature: mean=3.7657, std=8.0820
# Epoch 40/100:
#   Train Loss: 0.8331 (Class: 0.9741, Recon: 0.3558)
#   Train Acc: 58.48%, Test Acc: 50.00%
#   Curvature: mean=3.2226, std=6.5770
# Epoch 50/100:
#   Train Loss: 0.7956 (Class: 0.9226, Recon: 0.3815)
#   Train Acc: 58.93%, Test Acc: 50.00%
#   Curvature: mean=2.8611, std=5.7195
# Epoch 60/100:
#   Train Loss: 0.7549 (Class: 0.8892, Recon: 0.3592)
#   Train Acc: 62.50%, Test Acc: 50.00%
#   Curvature: mean=2.5219, std=4.5724
# Epoch 70/100:
#   Train Loss: 0.7347 (Class: 0.8730, Recon: 0.3343)
#   Train Acc: 64.73%, Test Acc: 50.00%
#   Curvature: mean=2.3446, std=5.0208
# Epoch 80/100:
#   Train Loss: 0.6770 (Class: 0.7975, Recon: 0.3151)
#   Train Acc: 69.20%, Test Acc: 50.00%
#   Curvature: mean=2.2294, std=4.6357
# Epoch 90/100:
#   Train Loss: 0.6836 (Class: 0.8174, Recon: 0.3042)
#   Train Acc: 68.30%, Test Acc: 50.00%
#   Curvature: mean=2.2123, std=4.7452
# Epoch 100/100:
#   Train Loss: 0.6895 (Class: 0.8227, Recon: 0.3084)
#   Train Acc: 66.52%, Test Acc: 50.00%
#   Curvature: mean=2.2375, std=4.7188
#
# Final Results:
#   Train Accuracy: 66.5%
#   Test Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
#   DEBUG - curvature attention weights:
#     Range: [0.0077, 1.2042]
#     Mean: 0.4380, Std: 0.3214
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/curvature/attention_time_curvature_8D_trial2.pth
#
# === Curvature Model Trial 4/5 (time split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Loss: 1.5419 (Class: 1.0359, Recon: 0.6969)
#   Train Acc: 54.02%, Test Acc: 42.65%
#   Curvature: mean=8.9912, std=18.5962
# Epoch 20/100:
#   Train Loss: 1.0647 (Class: 1.0423, Recon: 0.5437)
#   Train Acc: 56.70%, Test Acc: 50.00%
#   Curvature: mean=5.5717, std=10.4342
# Epoch 30/100:
#   Train Loss: 0.9161 (Class: 0.9958, Recon: 0.4403)
#   Train Acc: 56.70%, Test Acc: 50.00%
#   Curvature: mean=4.0203, std=8.2599
# Epoch 40/100:
#   Train Loss: 0.8400 (Class: 0.9986, Recon: 0.3695)
#   Train Acc: 57.14%, Test Acc: 50.00%
#   Curvature: mean=3.2077, std=6.5225
# Epoch 50/100:
#   Train Loss: 0.7818 (Class: 0.9700, Recon: 0.3173)
#   Train Acc: 57.14%, Test Acc: 50.00%
#   Curvature: mean=2.4226, std=5.0670
# Epoch 60/100:
#   Train Loss: 0.7512 (Class: 0.9440, Recon: 0.2997)
#   Train Acc: 57.14%, Test Acc: 50.00%
#   Curvature: mean=2.4061, std=5.0474
# Epoch 70/100:
#   Train Loss: 0.7349 (Class: 0.9236, Recon: 0.3034)
#   Train Acc: 59.82%, Test Acc: 50.00%
#   Curvature: mean=2.2224, std=4.4922
# Epoch 80/100:
#   Train Loss: 0.7317 (Class: 0.9221, Recon: 0.2956)
#   Train Acc: 58.48%, Test Acc: 50.00%
#   Curvature: mean=2.2795, std=4.8593
# Epoch 90/100:
#   Train Loss: 0.7207 (Class: 0.9148, Recon: 0.2846)
#   Train Acc: 60.27%, Test Acc: 50.00%
#   Curvature: mean=2.2172, std=4.3682
# Epoch 100/100:
#   Train Loss: 0.7352 (Class: 0.9353, Recon: 0.2912)
#   Train Acc: 58.04%, Test Acc: 50.00%
#   Curvature: mean=2.1867, std=4.4322
#
# Final Results:
#   Train Accuracy: 58.0%
#   Test Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
#   DEBUG - curvature attention weights:
#     Range: [0.0033, 1.2584]
#     Mean: 0.3929, Std: 0.2756
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/curvature/attention_time_curvature_8D_trial3.pth
#
# === Curvature Model Trial 5/5 (time split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Loss: 1.5121 (Class: 1.0007, Recon: 0.6676)
#   Train Acc: 57.59%, Test Acc: 45.59%
#   Curvature: mean=9.5764, std=19.9339
# Epoch 20/100:
#   Train Loss: 1.0747 (Class: 1.0337, Recon: 0.5393)
#   Train Acc: 55.80%, Test Acc: 38.24%
#   Curvature: mean=5.7059, std=12.0812
# Epoch 30/100:
#   Train Loss: 0.9034 (Class: 0.9894, Recon: 0.4213)
#   Train Acc: 56.70%, Test Acc: 50.00%
#   Curvature: mean=4.3009, std=8.1819
# Epoch 40/100:
#   Train Loss: 0.8473 (Class: 0.9941, Recon: 0.3678)
#   Train Acc: 57.14%, Test Acc: 48.53%
#   Curvature: mean=3.5559, std=7.6578
# Epoch 50/100:
#   Train Loss: 0.8284 (Class: 0.9669, Recon: 0.4059)
#   Train Acc: 57.14%, Test Acc: 50.00%
#   Curvature: mean=3.2677, std=6.8366
# Epoch 60/100:
#   Train Loss: 0.7945 (Class: 0.9909, Recon: 0.3082)
#   Train Acc: 56.70%, Test Acc: 39.71%
#   Curvature: mean=2.6360, std=5.0337
# Epoch 70/100:
#   Train Loss: 0.7611 (Class: 0.9575, Recon: 0.2924)
#   Train Acc: 57.14%, Test Acc: 25.00%
#   Curvature: mean=2.3844, std=4.3492
# Epoch 80/100:
#   Train Loss: 0.7510 (Class: 0.9560, Recon: 0.2792)
#   Train Acc: 57.14%, Test Acc: 25.00%
#   Curvature: mean=2.3651, std=4.5245
# Epoch 90/100:
#   Train Loss: 0.7494 (Class: 0.9493, Recon: 0.2855)
#   Train Acc: 57.59%, Test Acc: 25.00%
#   Curvature: mean=2.3372, std=4.6433
# Epoch 100/100:
#   Train Loss: 0.7202 (Class: 0.9090, Recon: 0.2772)
#   Train Acc: 58.93%, Test Acc: 25.00%
#   Curvature: mean=2.3193, std=4.4171
#
# Final Results:
#   Train Accuracy: 58.9%
#   Test Accuracy: 25.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.00      0.00      0.00        34
#       Improv       0.25      1.00      0.40        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.25        68
#    macro avg       0.08      0.33      0.13        68
# weighted avg       0.06      0.25      0.10        68
#
#   DEBUG - curvature attention weights:
#     Range: [0.0184, 1.1916]
#     Mean: 0.3505, Std: 0.2449
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/curvature/attention_time_curvature_8D_trial4.pth
# Results saved to: /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/curvature_results/curvature_time_8d_cv_results.pkl
#
# === Curvature Results (time split, 8D) ===
# Accuracy: 44.7% ± 9.9%
#
# --- LATENT DIMENSION: 48 ---
#
# SUBJECT SPLIT:
#
# === Curvature Model Trial 1/5 (subject split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['14091102', '14091701', '15053001sub2', '16100801', '15012001', '15040901', '16101401', '15111101', '15081202sub2', '15080601', '16100101', '15052902', '16100601', '15053001sub1']
#   Test subjects (3): ['14092201', '16102002', '14101601']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Loss: 1.0284 (Class: 0.9839, Recon: 0.4091)
#   Train Acc: 54.58%, Test Acc: 55.56%
#   Curvature: mean=6.0375, std=9.6954
# Epoch 20/100:
#   Train Loss: 0.8672 (Class: 0.9864, Recon: 0.3328)
#   Train Acc: 54.17%, Test Acc: 42.59%
#   Curvature: mean=4.7719, std=8.2918
# Epoch 30/100:
#   Train Loss: 0.6935 (Class: 0.7861, Recon: 0.3029)
#   Train Acc: 66.67%, Test Acc: 38.89%
#   Curvature: mean=2.7970, std=4.3380
# Epoch 40/100:
#   Train Loss: 0.6018 (Class: 0.6990, Recon: 0.2539)
#   Train Acc: 68.33%, Test Acc: 37.04%
#   Curvature: mean=2.6723, std=4.6461
# Epoch 50/100:
#   Train Loss: 0.5299 (Class: 0.6182, Recon: 0.2379)
#   Train Acc: 70.83%, Test Acc: 40.74%
#   Curvature: mean=1.8345, std=2.4506
# Epoch 60/100:
#   Train Loss: 0.4494 (Class: 0.5119, Recon: 0.2135)
#   Train Acc: 79.58%, Test Acc: 42.59%
#   Curvature: mean=1.8717, std=2.6835
# Epoch 70/100:
#   Train Loss: 0.3833 (Class: 0.4313, Recon: 0.1809)
#   Train Acc: 84.17%, Test Acc: 48.15%
#   Curvature: mean=1.7625, std=2.5667
# Epoch 80/100:
#   Train Loss: 0.3472 (Class: 0.3804, Recon: 0.1719)
#   Train Acc: 86.25%, Test Acc: 46.30%
#   Curvature: mean=1.7780, std=2.4367
# Epoch 90/100:
#   Train Loss: 0.3858 (Class: 0.4421, Recon: 0.1755)
#   Train Acc: 84.17%, Test Acc: 46.30%
#   Curvature: mean=1.7422, std=2.3711
# Epoch 100/100:
#   Train Loss: 0.3853 (Class: 0.4338, Recon: 0.1867)
#   Train Acc: 84.17%, Test Acc: 44.44%
#   Curvature: mean=1.7192, std=2.3562
#
# Final Results:
#   Train Accuracy: 84.2%
#   Test Accuracy: 44.4%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.51      0.70      0.59        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.23      0.25      0.24        12
#
#     accuracy                           0.44        54
#    macro avg       0.25      0.32      0.28        54
# weighted avg       0.34      0.44      0.38        54
#
#   DEBUG - curvature attention weights:
#     Range: [0.0047, 1.0109]
#     Mean: 0.4395, Std: 0.2530
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/curvature/attention_subject_curvature_48D_trial0.pth
#
# === Curvature Model Trial 2/5 (subject split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15111101', '15052902', '14091701', '15080601', '15053001sub1', '15040901', '15053001sub2', '16100601', '14091102', '16100101', '14101601', '16102002', '14092201', '15081202sub2']
#   Test subjects (3): ['15012001', '16101401', '16100801']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Loss: 1.0672 (Class: 1.0604, Recon: 0.4288)
#   Train Acc: 54.17%, Test Acc: 31.48%
#   Curvature: mean=4.5904, std=7.5429
# Epoch 20/100:
#   Train Loss: 0.8423 (Class: 0.9883, Recon: 0.2954)
#   Train Acc: 56.25%, Test Acc: 22.22%
#   Curvature: mean=3.0063, std=5.2145
# Epoch 30/100:
#   Train Loss: 0.7474 (Class: 0.9019, Recon: 0.2807)
#   Train Acc: 61.25%, Test Acc: 20.37%
#   Curvature: mean=2.1824, std=3.3499
# Epoch 40/100:
#   Train Loss: 0.6504 (Class: 0.7981, Recon: 0.2197)
#   Train Acc: 66.67%, Test Acc: 31.48%
#   Curvature: mean=1.5406, std=2.7356
# Epoch 50/100:
#   Train Loss: 0.4952 (Class: 0.6006, Recon: 0.1785)
#   Train Acc: 72.50%, Test Acc: 29.63%
#   Curvature: mean=1.3724, std=2.3932
# Epoch 60/100:
#   Train Loss: 0.5155 (Class: 0.6110, Recon: 0.2275)
#   Train Acc: 75.00%, Test Acc: 44.44%
#   Curvature: mean=1.2731, std=2.3384
# Epoch 70/100:
#   Train Loss: 0.4078 (Class: 0.4670, Recon: 0.1841)
#   Train Acc: 82.08%, Test Acc: 38.89%
#   Curvature: mean=1.1921, std=1.9732
# Epoch 80/100:
#   Train Loss: 0.3786 (Class: 0.4403, Recon: 0.1630)
#   Train Acc: 80.42%, Test Acc: 37.04%
#   Curvature: mean=1.0948, std=1.7870
# Epoch 90/100:
#   Train Loss: 0.3816 (Class: 0.4437, Recon: 0.1712)
#   Train Acc: 84.17%, Test Acc: 35.19%
#   Curvature: mean=1.0707, std=1.6698
# Epoch 100/100:
#   Train Loss: 0.3496 (Class: 0.3982, Recon: 0.1617)
#   Train Acc: 85.00%, Test Acc: 38.89%
#   Curvature: mean=1.0364, std=1.6363
#
# Final Results:
#   Train Accuracy: 85.0%
#   Test Accuracy: 38.9%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.79      0.37      0.50        30
#       Improv       0.26      0.83      0.39        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.39        54
#    macro avg       0.35      0.40      0.30        54
# weighted avg       0.49      0.39      0.36        54
#
#   DEBUG - curvature attention weights:
#     Range: [0.0091, 0.9665]
#     Mean: 0.3583, Std: 0.2935
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/curvature/attention_subject_curvature_48D_trial1.pth
#
# === Curvature Model Trial 3/5 (subject split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['16100101', '16101401', '14091102', '15053001sub1', '15080601', '16100801', '15052902', '15081202sub2', '14092201', '15111101', '14091701', '15012001', '16102002', '16100601']
#   Test subjects (3): ['15053001sub2', '14101601', '15040901']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Loss: 1.0221 (Class: 1.0304, Recon: 0.3642)
#   Train Acc: 52.92%, Test Acc: 55.56%
#   Curvature: mean=5.7555, std=8.8922
# Epoch 20/100:
#   Train Loss: 0.8527 (Class: 0.9883, Recon: 0.3349)
#   Train Acc: 55.83%, Test Acc: 55.56%
#   Curvature: mean=3.7422, std=6.0799
# Epoch 30/100:
#   Train Loss: 0.7690 (Class: 0.9654, Recon: 0.2659)
#   Train Acc: 56.25%, Test Acc: 55.56%
#   Curvature: mean=2.7329, std=4.5529
# Epoch 40/100:
#   Train Loss: 0.7035 (Class: 0.8934, Recon: 0.2445)
#   Train Acc: 58.75%, Test Acc: 55.56%
#   Curvature: mean=1.8016, std=3.2078
# Epoch 50/100:
#   Train Loss: 0.6491 (Class: 0.8108, Recon: 0.2582)
#   Train Acc: 66.67%, Test Acc: 57.41%
#   Curvature: mean=1.3950, std=2.4884
# Epoch 60/100:
#   Train Loss: 0.5159 (Class: 0.6547, Recon: 0.1883)
#   Train Acc: 69.58%, Test Acc: 57.41%
#   Curvature: mean=1.2618, std=2.1064
# Epoch 70/100:
#   Train Loss: 0.5028 (Class: 0.6428, Recon: 0.1813)
#   Train Acc: 71.67%, Test Acc: 57.41%
#   Curvature: mean=1.1644, std=1.7929
# Epoch 80/100:
#   Train Loss: 0.4624 (Class: 0.5698, Recon: 0.1924)
#   Train Acc: 74.58%, Test Acc: 55.56%
#   Curvature: mean=1.1399, std=1.7435
# Epoch 90/100:
#   Train Loss: 0.4748 (Class: 0.6009, Recon: 0.1771)
#   Train Acc: 74.58%, Test Acc: 55.56%
#   Curvature: mean=1.1101, std=1.6947
# Epoch 100/100:
#   Train Loss: 0.4624 (Class: 0.5830, Recon: 0.1768)
#   Train Acc: 75.83%, Test Acc: 55.56%
#   Curvature: mean=1.1054, std=1.6293
#
# Final Results:
#   Train Accuracy: 75.8%
#   Test Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
#   DEBUG - curvature attention weights:
#     Range: [0.0062, 1.0654]
#     Mean: 0.3602, Std: 0.2579
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/curvature/attention_subject_curvature_48D_trial2.pth
#
# === Curvature Model Trial 4/5 (subject split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15040901', '15053001sub1', '15111101', '16102002', '15080601', '16100801', '15081202sub2', '14091102', '14101601', '14092201', '15052902', '16100601', '15053001sub2', '14091701']
#   Test subjects (3): ['16100101', '16101401', '15012001']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Loss: 1.0031 (Class: 0.9839, Recon: 0.3483)
#   Train Acc: 56.67%, Test Acc: 59.26%
#   Curvature: mean=6.5387, std=12.6393
# Epoch 20/100:
#   Train Loss: 0.8372 (Class: 0.9381, Recon: 0.3021)
#   Train Acc: 60.42%, Test Acc: 33.33%
#   Curvature: mean=4.0038, std=6.7971
# Epoch 30/100:
#   Train Loss: 0.6923 (Class: 0.7925, Recon: 0.2797)
#   Train Acc: 67.50%, Test Acc: 37.04%
#   Curvature: mean=2.6667, std=4.1536
# Epoch 40/100:
#   Train Loss: 0.5938 (Class: 0.6949, Recon: 0.2371)
#   Train Acc: 69.17%, Test Acc: 40.74%
#   Curvature: mean=2.3683, std=3.7141
# Epoch 50/100:
#   Train Loss: 0.5014 (Class: 0.5825, Recon: 0.2079)
#   Train Acc: 72.92%, Test Acc: 50.00%
#   Curvature: mean=1.8015, std=2.7231
# Epoch 60/100:
#   Train Loss: 0.4278 (Class: 0.5017, Recon: 0.1823)
#   Train Acc: 78.33%, Test Acc: 46.30%
#   Curvature: mean=1.6952, std=2.4033
# Epoch 70/100:
#   Train Loss: 0.3554 (Class: 0.4083, Recon: 0.1529)
#   Train Acc: 78.75%, Test Acc: 50.00%
#   Curvature: mean=1.5530, std=2.2232
# Epoch 80/100:
#   Train Loss: 0.3666 (Class: 0.4297, Recon: 0.1519)
#   Train Acc: 85.42%, Test Acc: 51.85%
#   Curvature: mean=1.5166, std=2.1382
# Epoch 90/100:
#   Train Loss: 0.3402 (Class: 0.3866, Recon: 0.1522)
#   Train Acc: 82.08%, Test Acc: 51.85%
#   Curvature: mean=1.4839, std=2.1068
# Epoch 100/100:
#   Train Loss: 0.3649 (Class: 0.4182, Recon: 0.1641)
#   Train Acc: 82.92%, Test Acc: 51.85%
#   Curvature: mean=1.5268, std=2.1621
#
# Final Results:
#   Train Accuracy: 82.9%
#   Test Accuracy: 51.9%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.82      0.60      0.69        30
#       Improv       0.31      0.83      0.45        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.52        54
#    macro avg       0.38      0.48      0.38        54
# weighted avg       0.52      0.52      0.49        54
#
#   DEBUG - curvature attention weights:
#     Range: [0.0055, 1.2861]
#     Mean: 0.4194, Std: 0.3126
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/curvature/attention_subject_curvature_48D_trial3.pth
#
# === Curvature Model Trial 5/5 (subject split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15053001sub2', '15052902', '16101401', '15053001sub1', '15012001', '14091102', '14091701', '14092201', '15040901', '16100601', '16100101', '15081202sub2', '16100801', '14101601']
#   Test subjects (3): ['16102002', '15080601', '15111101']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Loss: 1.0299 (Class: 0.9898, Recon: 0.3945)
#   Train Acc: 56.25%, Test Acc: 50.00%
#   Curvature: mean=5.6910, std=10.5458
# Epoch 20/100:
#   Train Loss: 0.8153 (Class: 0.9153, Recon: 0.3096)
#   Train Acc: 59.17%, Test Acc: 42.59%
#   Curvature: mean=3.4659, std=6.3343
# Epoch 30/100:
#   Train Loss: 0.7353 (Class: 0.8566, Recon: 0.3083)
#   Train Acc: 63.75%, Test Acc: 53.70%
#   Curvature: mean=2.7042, std=5.6538
# Epoch 40/100:
#   Train Loss: 0.6161 (Class: 0.7096, Recon: 0.2768)
#   Train Acc: 68.33%, Test Acc: 51.85%
#   Curvature: mean=1.9982, std=3.1935
# Epoch 50/100:
#   Train Loss: 0.5917 (Class: 0.6937, Recon: 0.2488)
#   Train Acc: 71.25%, Test Acc: 46.30%
#   Curvature: mean=1.7135, std=2.8439
# Epoch 60/100:
#   Train Loss: 0.4990 (Class: 0.5932, Recon: 0.2119)
#   Train Acc: 74.58%, Test Acc: 51.85%
#   Curvature: mean=1.5850, std=2.4627
# Epoch 70/100:
#   Train Loss: 0.4011 (Class: 0.4742, Recon: 0.1689)
#   Train Acc: 81.25%, Test Acc: 51.85%
#   Curvature: mean=1.5176, std=2.5519
# Epoch 80/100:
#   Train Loss: 0.3280 (Class: 0.3477, Recon: 0.1815)
#   Train Acc: 87.50%, Test Acc: 51.85%
#   Curvature: mean=1.4999, std=2.4176
# Epoch 90/100:
#   Train Loss: 0.3941 (Class: 0.4475, Recon: 0.1997)
#   Train Acc: 80.42%, Test Acc: 48.15%
#   Curvature: mean=1.4797, std=2.3666
# Epoch 100/100:
#   Train Loss: 0.3740 (Class: 0.4307, Recon: 0.1752)
#   Train Acc: 82.92%, Test Acc: 51.85%
#   Curvature: mean=1.4804, std=2.4299
#
# Final Results:
#   Train Accuracy: 82.9%
#   Test Accuracy: 51.9%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.55      0.93      0.69        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.52        54
#    macro avg       0.18      0.31      0.23        54
# weighted avg       0.31      0.52      0.38        54
#
#   DEBUG - curvature attention weights:
#     Range: [0.0161, 1.3482]
#     Mean: 0.4245, Std: 0.3021
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/curvature/attention_subject_curvature_48D_trial4.pth
# Results saved to: /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/curvature_results/curvature_subject_48d_cv_results.pkl
#
# === Curvature Results (subject split, 48D) ===
# Accuracy: 48.5% ± 6.0%
#
# TIME SPLIT:
#
# === Curvature Model Trial 1/5 (time split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Loss: 1.0391 (Class: 0.9986, Recon: 0.4161)
#   Train Acc: 55.80%, Test Acc: 50.00%
#   Curvature: mean=6.4584, std=10.2159
# Epoch 20/100:
#   Train Loss: 0.8352 (Class: 0.9190, Recon: 0.3363)
#   Train Acc: 62.95%, Test Acc: 50.00%
#   Curvature: mean=4.5007, std=8.0634
# Epoch 30/100:
#   Train Loss: 0.7119 (Class: 0.8189, Recon: 0.2967)
#   Train Acc: 68.75%, Test Acc: 50.00%
#   Curvature: mean=2.9569, std=4.7955
# Epoch 40/100:
#   Train Loss: 0.6187 (Class: 0.6944, Recon: 0.2959)
#   Train Acc: 71.88%, Test Acc: 44.12%
#   Curvature: mean=2.4252, std=4.1871
# Epoch 50/100:
#   Train Loss: 0.5476 (Class: 0.6590, Recon: 0.2132)
#   Train Acc: 73.66%, Test Acc: 35.29%
#   Curvature: mean=2.2450, std=4.5455
# Epoch 60/100:
#   Train Loss: 0.4444 (Class: 0.5255, Recon: 0.1824)
#   Train Acc: 75.89%, Test Acc: 35.29%
#   Curvature: mean=1.9840, std=3.8482
# Epoch 70/100:
#   Train Loss: 0.4197 (Class: 0.4836, Recon: 0.1940)
#   Train Acc: 79.46%, Test Acc: 44.12%
#   Curvature: mean=1.9369, std=3.2010
# Epoch 80/100:
#   Train Loss: 0.3904 (Class: 0.4477, Recon: 0.1780)
#   Train Acc: 80.36%, Test Acc: 36.76%
#   Curvature: mean=1.8477, std=2.9417
# Epoch 90/100:
#   Train Loss: 0.3486 (Class: 0.3732, Recon: 0.1909)
#   Train Acc: 87.05%, Test Acc: 39.71%
#   Curvature: mean=1.8342, std=2.9148
# Epoch 100/100:
#   Train Loss: 0.4068 (Class: 0.4839, Recon: 0.1730)
#   Train Acc: 80.36%, Test Acc: 41.18%
#   Curvature: mean=1.8259, std=2.8493
#
# Final Results:
#   Train Accuracy: 80.4%
#   Test Accuracy: 41.2%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.65      0.50      0.57        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.26      0.65      0.37        17
#
#     accuracy                           0.41        68
#    macro avg       0.31      0.38      0.31        68
# weighted avg       0.39      0.41      0.38        68
#
#   DEBUG - curvature attention weights:
#     Range: [0.0278, 1.3368]
#     Mean: 0.4306, Std: 0.3157
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/curvature/attention_time_curvature_48D_trial0.pth
#
# === Curvature Model Trial 2/5 (time split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Loss: 1.0553 (Class: 0.9945, Recon: 0.4252)
#   Train Acc: 57.59%, Test Acc: 50.00%
#   Curvature: mean=5.7395, std=9.7981
# Epoch 20/100:
#   Train Loss: 0.8488 (Class: 0.9638, Recon: 0.3106)
#   Train Acc: 58.48%, Test Acc: 50.00%
#   Curvature: mean=4.0335, std=6.6858
# Epoch 30/100:
#   Train Loss: 0.6988 (Class: 0.8346, Recon: 0.2430)
#   Train Acc: 64.73%, Test Acc: 50.00%
#   Curvature: mean=2.8785, std=5.4625
# Epoch 40/100:
#   Train Loss: 0.6166 (Class: 0.7378, Recon: 0.2285)
#   Train Acc: 67.86%, Test Acc: 47.06%
#   Curvature: mean=2.6551, std=4.6367
# Epoch 50/100:
#   Train Loss: 0.5280 (Class: 0.6194, Recon: 0.2164)
#   Train Acc: 74.55%, Test Acc: 36.76%
#   Curvature: mean=1.8655, std=3.3241
# Epoch 60/100:
#   Train Loss: 0.5776 (Class: 0.7132, Recon: 0.2135)
#   Train Acc: 71.43%, Test Acc: 33.82%
#   Curvature: mean=1.7083, std=3.0277
# Epoch 70/100:
#   Train Loss: 0.4332 (Class: 0.5169, Recon: 0.1818)
#   Train Acc: 78.57%, Test Acc: 35.29%
#   Curvature: mean=1.4452, std=2.5311
# Epoch 80/100:
#   Train Loss: 0.3630 (Class: 0.4314, Recon: 0.1467)
#   Train Acc: 81.25%, Test Acc: 36.76%
#   Curvature: mean=1.4431, std=2.6377
# Epoch 90/100:
#   Train Loss: 0.3671 (Class: 0.4392, Recon: 0.1531)
#   Train Acc: 83.48%, Test Acc: 38.24%
#   Curvature: mean=1.4282, std=2.4917
# Epoch 100/100:
#   Train Loss: 0.3638 (Class: 0.4289, Recon: 0.1641)
#   Train Acc: 82.14%, Test Acc: 39.71%
#   Curvature: mean=1.3564, std=2.4334
#
# Final Results:
#   Train Accuracy: 82.1%
#   Test Accuracy: 39.7%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.52      0.76      0.62        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.06      0.06      0.06        17
#
#     accuracy                           0.40        68
#    macro avg       0.19      0.27      0.23        68
# weighted avg       0.27      0.40      0.32        68
#
#   DEBUG - curvature attention weights:
#     Range: [0.0120, 1.5253]
#     Mean: 0.4484, Std: 0.3132
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/curvature/attention_time_curvature_48D_trial1.pth
#
# === Curvature Model Trial 3/5 (time split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Loss: 1.0270 (Class: 0.9902, Recon: 0.3701)
#   Train Acc: 55.80%, Test Acc: 44.12%
#   Curvature: mean=6.8965, std=11.4038
# Epoch 20/100:
#   Train Loss: 0.8318 (Class: 0.9042, Recon: 0.3493)
#   Train Acc: 57.59%, Test Acc: 30.88%
#   Curvature: mean=4.5423, std=7.7695
# Epoch 30/100:
#   Train Loss: 0.7401 (Class: 0.8235, Recon: 0.3497)
#   Train Acc: 66.07%, Test Acc: 42.65%
#   Curvature: mean=3.3637, std=5.4355
# Epoch 40/100:
#   Train Loss: 0.5988 (Class: 0.6807, Recon: 0.2553)
#   Train Acc: 69.20%, Test Acc: 36.76%
#   Curvature: mean=2.4759, std=3.9516
# Epoch 50/100:
#   Train Loss: 0.5009 (Class: 0.5782, Recon: 0.2077)
#   Train Acc: 73.21%, Test Acc: 35.29%
#   Curvature: mean=2.3390, std=4.5995
# Epoch 60/100:
#   Train Loss: 0.4156 (Class: 0.4708, Recon: 0.1893)
#   Train Acc: 82.14%, Test Acc: 39.71%
#   Curvature: mean=1.9897, std=3.3188
# Epoch 70/100:
#   Train Loss: 0.3698 (Class: 0.4079, Recon: 0.1814)
#   Train Acc: 83.93%, Test Acc: 42.65%
#   Curvature: mean=1.9099, std=3.2781
# Epoch 80/100:
#   Train Loss: 0.4125 (Class: 0.4753, Recon: 0.1895)
#   Train Acc: 79.46%, Test Acc: 42.65%
#   Curvature: mean=1.8880, std=3.2835
# Epoch 90/100:
#   Train Loss: 0.3475 (Class: 0.3834, Recon: 0.1662)
#   Train Acc: 86.61%, Test Acc: 41.18%
#   Curvature: mean=1.8602, std=3.2051
# Epoch 100/100:
#   Train Loss: 0.3824 (Class: 0.4294, Recon: 0.1864)
#   Train Acc: 82.59%, Test Acc: 41.18%
#   Curvature: mean=1.8720, std=3.2222
#
# Final Results:
#   Train Accuracy: 82.6%
#   Test Accuracy: 41.2%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      0.65      0.56        34
#       Improv       1.00      0.18      0.30        17
#        Scale       0.14      0.18      0.16        17
#
#     accuracy                           0.41        68
#    macro avg       0.55      0.33      0.34        68
# weighted avg       0.54      0.41      0.40        68
#
#   DEBUG - curvature attention weights:
#     Range: [0.0113, 1.2015]
#     Mean: 0.4657, Std: 0.2694
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/curvature/attention_time_curvature_48D_trial2.pth
#
# === Curvature Model Trial 4/5 (time split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Loss: 1.0464 (Class: 0.9979, Recon: 0.4024)
#   Train Acc: 54.46%, Test Acc: 39.71%
#   Curvature: mean=6.6315, std=9.7547
# Epoch 20/100:
#   Train Loss: 0.8291 (Class: 0.9046, Recon: 0.3352)
#   Train Acc: 61.16%, Test Acc: 50.00%
#   Curvature: mean=4.1047, std=6.8414
# Epoch 30/100:
#   Train Loss: 0.7345 (Class: 0.8421, Recon: 0.2935)
#   Train Acc: 65.62%, Test Acc: 50.00%
#   Curvature: mean=3.5894, std=6.2913
# Epoch 40/100:
#   Train Loss: 0.6300 (Class: 0.7554, Recon: 0.2300)
#   Train Acc: 65.62%, Test Acc: 45.59%
#   Curvature: mean=2.3875, std=4.3876
# Epoch 50/100:
#   Train Loss: 0.5538 (Class: 0.6414, Recon: 0.2436)
#   Train Acc: 71.88%, Test Acc: 48.53%
#   Curvature: mean=2.0248, std=3.8482
# Epoch 60/100:
#   Train Loss: 0.4704 (Class: 0.5347, Recon: 0.2260)
#   Train Acc: 75.45%, Test Acc: 48.53%
#   Curvature: mean=1.8645, std=3.4843
# Epoch 70/100:
#   Train Loss: 0.4401 (Class: 0.5288, Recon: 0.1804)
#   Train Acc: 77.23%, Test Acc: 39.71%
#   Curvature: mean=1.6510, std=2.5306
# Epoch 80/100:
#   Train Loss: 0.3729 (Class: 0.4309, Recon: 0.1704)
#   Train Acc: 80.80%, Test Acc: 42.65%
#   Curvature: mean=1.5491, std=2.8572
# Epoch 90/100:
#   Train Loss: 0.3615 (Class: 0.4231, Recon: 0.1607)
#   Train Acc: 81.70%, Test Acc: 39.71%
#   Curvature: mean=1.5339, std=2.9547
# Epoch 100/100:
#   Train Loss: 0.3543 (Class: 0.4085, Recon: 0.1639)
#   Train Acc: 82.14%, Test Acc: 38.24%
#   Curvature: mean=1.5350, std=2.8379
#
# Final Results:
#   Train Accuracy: 82.1%
#   Test Accuracy: 38.2%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.47      0.74      0.57        34
#       Improv       0.25      0.06      0.10        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.38        68
#    macro avg       0.24      0.26      0.22        68
# weighted avg       0.30      0.38      0.31        68
#
#   DEBUG - curvature attention weights:
#     Range: [0.0045, 1.0818]
#     Mean: 0.3419, Std: 0.2546
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/curvature/attention_time_curvature_48D_trial3.pth
#
# === Curvature Model Trial 5/5 (time split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Loss: 1.0426 (Class: 1.0072, Recon: 0.3730)
#   Train Acc: 55.80%, Test Acc: 39.71%
#   Curvature: mean=6.4686, std=10.9784
# Epoch 20/100:
#   Train Loss: 0.8086 (Class: 0.8836, Recon: 0.3093)
#   Train Acc: 64.29%, Test Acc: 33.82%
#   Curvature: mean=4.4474, std=7.9208
# Epoch 30/100:
#   Train Loss: 0.7245 (Class: 0.8239, Recon: 0.2994)
#   Train Acc: 64.29%, Test Acc: 39.71%
#   Curvature: mean=3.0520, std=4.9143
# Epoch 40/100:
#   Train Loss: 0.5961 (Class: 0.6570, Recon: 0.2770)
#   Train Acc: 70.98%, Test Acc: 39.71%
#   Curvature: mean=2.4438, std=4.2857
# Epoch 50/100:
#   Train Loss: 0.4916 (Class: 0.5453, Recon: 0.2366)
#   Train Acc: 75.89%, Test Acc: 36.76%
#   Curvature: mean=2.0431, std=3.0681
# Epoch 60/100:
#   Train Loss: 0.4058 (Class: 0.4359, Recon: 0.2009)
#   Train Acc: 82.59%, Test Acc: 39.71%
#   Curvature: mean=1.9005, std=2.7316
# Epoch 70/100:
#   Train Loss: 0.4129 (Class: 0.4841, Recon: 0.1595)
#   Train Acc: 79.02%, Test Acc: 41.18%
#   Curvature: mean=1.7560, std=2.5445
# Epoch 80/100:
#   Train Loss: 0.3908 (Class: 0.4409, Recon: 0.1752)
#   Train Acc: 82.59%, Test Acc: 42.65%
#   Curvature: mean=1.7416, std=2.4578
# Epoch 90/100:
#   Train Loss: 0.3667 (Class: 0.3979, Recon: 0.1822)
#   Train Acc: 82.59%, Test Acc: 39.71%
#   Curvature: mean=1.7582, std=2.4280
# Epoch 100/100:
#   Train Loss: 0.3072 (Class: 0.2983, Recon: 0.1830)
#   Train Acc: 88.84%, Test Acc: 39.71%
#   Curvature: mean=1.7127, std=2.3471
#
# Final Results:
#   Train Accuracy: 88.8%
#   Test Accuracy: 39.7%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.92      0.32      0.48        34
#       Improv       0.29      0.94      0.44        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.40        68
#    macro avg       0.40      0.42      0.31        68
# weighted avg       0.53      0.40      0.35        68
#
#   DEBUG - curvature attention weights:
#     Range: [0.0012, 0.9089]
#     Mean: 0.3698, Std: 0.2524
# ✓ Attention weights saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/attention_results/curvature/attention_time_curvature_48D_trial4.pth
# Results saved to: /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/curvature_results/curvature_time_48d_cv_results.pkl
#
# === Curvature Results (time split, 48D) ===
# Accuracy: 40.0% ± 1.1%
#
# ✓ Results saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/curvature_results/curvature_cv_results.pkl
#
# === CROSS-VALIDATION SUMMARY ===
#
# 8D Latent Space:
#   Subject: 48.9% ± 13.3%
#   Time: 44.7% ± 9.9%
#
# 48D Latent Space:
#   Subject: 48.5% ± 6.0%
#   Time: 40.0% ± 1.1%
