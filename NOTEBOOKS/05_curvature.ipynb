# %%
### SETUP ###
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import pickle
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings('ignore')
from SCRIPTS.config import *
from SCRIPTS.dataprep import prepare_interval_data
from SCRIPTS.curvature_models import CurvatureModel
from SCRIPTS.curvature_training import train_curvature_model, evaluate_model, IntervalDataset
from SCRIPTS.cross_validation_experiments import run_curvature_cross_validation

# Visualization setup
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("husl")

# Set random seed
np.random.seed(42)
torch.manual_seed(42)

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
print(f"Data path: {COMBINED_SCATTERING}")
print(f"Results path: {CURVATURE_RESULTS_DIR}")
# Out:
# Using device: cpu
# Data path: /Users/judesack/Neurospectrum_Creativity/DATA/SCATTERING_COEFFICIENTS/combined_scattering_data.csv
# Results path: /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/curvature_results

# %%
### CONFIGURATION ###

# Train curvature models? T/F
TRAIN_CURVATURE = False

# Run cross-validation? T/F
RUN_CROSS_VALIDATION = True

# Number of CV trials (set to 5)
CV_TRIALS = 5

# Latent dimensions to test
LATENT_DIMS = [8, 48]

# Reconstruction weight (0.3 means 30% reconstruction, 70% classification)
RECON_WEIGHT = 0.3

# %%
### LOAD INTERVAL DATA ###

print("\n=== LOADING INTERVAL DATA ===")
train_loader_subj, test_loader_subj, info_subj = prepare_interval_data(
    scattering_data_path=COMBINED_SCATTERING,
    split_type='subject',
    batch_size=16,
    random_state=42
)

train_loader_time, test_loader_time, info_time = prepare_interval_data(
    scattering_data_path=COMBINED_SCATTERING,
    split_type='time',
    batch_size=16,
    random_state=42
)

print(f"\nSubject split: {info_subj['n_train']} train, {info_subj['n_test']} test")
print(f"Time split: {info_time['n_train']} train, {info_time['n_test']} test")
# Out:
# === LOADING INTERVAL DATA ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15053001sub1', '16100101', '15111101', '15081202sub2', '14101601', '14092201', '14091102', '15053001sub2', '15052902', '14091701', '16101401', '16102002', '15040901', '16100801']
#   Test subjects (3): ['15080601', '15012001', '16100601']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
#
# Subject split: 252 train, 54 test
# Time split: 238 train, 68 test

# %%
### TRAIN CURVATURE MODELS ###

if TRAIN_CURVATURE:
    print("\n=== TRAINING CURVATURE MODELS ===")
    
    results = {}
    
    for latent_dim in LATENT_DIMS:
        print(f"\n--- Latent Dimension: {latent_dim} ---")
        results[latent_dim] = {}
        
        print("\nSUBJECT WITHHOLDING:")
        
        # Convert DataLoader to intervals for curvature training
        train_intervals = []
        for batch in train_loader_subj:
            features, labels, subjects, intervals = batch
            for i in range(len(features)):
                train_intervals.append((
                    features[i].numpy(),
                    labels[i].item(),
                    subjects[i],
                    intervals[i]
                ))
        
        test_intervals = []
        for batch in test_loader_subj:
            features, labels, subjects, intervals = batch
            for i in range(len(features)):
                test_intervals.append((
                    features[i].numpy(),
                    labels[i].item(),
                    subjects[i],
                    intervals[i]
                ))
        
        model, history = train_curvature_model(
            train_intervals=train_intervals,
            test_intervals=test_intervals,
            latent_dim=latent_dim,
            num_epochs=DEFAULT_EPOCHS,
            batch_size=16,
            learning_rate=DEFAULT_LEARNING_RATE,
            recon_weight=RECON_WEIGHT,
            device=device
        )
        
        results[latent_dim]['subject'] = {
            'accuracy': history['test_acc'][-1],
            'history': history,
            'model_state': model.state_dict()
        }
        
        save_path = CURVATURE_RESULTS_DIR / f'curvature_subject_{latent_dim}d.pth'
        torch.save({
            'model_state_dict': model.state_dict(),
            'history': history,
            'latent_dim': latent_dim,
            'split_type': 'subject'
        }, save_path)
        print(f"✓ Model saved to {save_path}")
        
        print("\nTIME WITHHOLDING:")
        
        train_intervals = []
        for batch in train_loader_time:
            features, labels, subjects, intervals = batch
            for i in range(len(features)):
                train_intervals.append((
                    features[i].numpy(),
                    labels[i].item(),
                    subjects[i],
                    intervals[i]
                ))
        
        test_intervals = []
        for batch in test_loader_time:
            features, labels, subjects, intervals = batch
            for i in range(len(features)):
                test_intervals.append((
                    features[i].numpy(),
                    labels[i].item(),
                    subjects[i],
                    intervals[i]
                ))
        
        model, history = train_curvature_model(
            train_intervals=train_intervals,
            test_intervals=test_intervals,
            latent_dim=latent_dim,
            num_epochs=DEFAULT_EPOCHS,
            batch_size=16,
            learning_rate=DEFAULT_LEARNING_RATE,
            recon_weight=RECON_WEIGHT,
            device=device
        )
        
        results[latent_dim]['time'] = {
            'accuracy': history['test_acc'][-1],
            'history': history,
            'model_state': model.state_dict()
        }
        
        save_path = CURVATURE_RESULTS_DIR / f'curvature_time_{latent_dim}d.pth'
        torch.save({
            'model_state_dict': model.state_dict(),
            'history': history,
            'latent_dim': latent_dim,
            'split_type': 'time'
        }, save_path)
        print(f"✓ Model saved to {save_path}")
    
    print("\n=== CURVATURE MODEL RESULTS ===")
    for latent_dim in LATENT_DIMS:
        print(f"\n{latent_dim}D Latent Space:")
        print(f"  Subject: {results[latent_dim]['subject']['accuracy']:.1f}%")
        print(f"  Time: {results[latent_dim]['time']['accuracy']:.1f}%")

else:
    print("✓ Skipping curvature model training")

# %%
### CROSS-VALIDATION ###

if RUN_CROSS_VALIDATION:
    print(f"\n=== CROSS-VALIDATION EXPERIMENTS ({CV_TRIALS} trials) ===")
    
    cv_results = {}
    
    for latent_dim in LATENT_DIMS:
        print(f"\n--- LATENT DIMENSION: {latent_dim} ---")
        cv_results[latent_dim] = {}
        
        for split_type in ['subject', 'time']:
            print(f"\n{split_type.upper()} SPLIT:")
            cv_results[latent_dim][split_type] = run_curvature_cross_validation(
                data_path=COMBINED_SCATTERING,
                split_type=split_type,
                latent_dim=latent_dim,
                num_trials=CV_TRIALS,
                num_epochs=DEFAULT_EPOCHS
            )
    
    # Save results
    save_path = CURVATURE_RESULTS_DIR / 'curvature_cv_results.pkl'
    with open(save_path, 'wb') as f:
        pickle.dump(cv_results, f)
    print(f"\n✓ Results saved to {save_path}")
    
    # Display summary
    print("\n=== CROSS-VALIDATION SUMMARY ===")
    for latent_dim in LATENT_DIMS:
        print(f"\n{latent_dim}D Latent Space:")
        print(f"  Subject: {cv_results[latent_dim]['subject']['mean_accuracy']:.1f}% ± {cv_results[latent_dim]['subject']['std_accuracy']:.1f}%")
        print(f"  Time: {cv_results[latent_dim]['time']['mean_accuracy']:.1f}% ± {cv_results[latent_dim]['time']['std_accuracy']:.1f}%")

else:
    # Load existing results
    cv_file = CURVATURE_RESULTS_DIR / 'curvature_cv_results.pkl'
    
    if cv_file.exists():
        with open(cv_file, 'rb') as f:
            cv_results = pickle.load(f)
        
        print("✓ Loaded existing cross-validation results")
        
        print("\n=== CROSS-VALIDATION SUMMARY ===")
        for latent_dim in LATENT_DIMS:
            if latent_dim in cv_results:
                print(f"\n{latent_dim}D Latent Space:")
                print(f"  Subject: {cv_results[latent_dim]['subject']['mean_accuracy']:.1f}% ± {cv_results[latent_dim]['subject']['std_accuracy']:.1f}%")
                print(f"  Time: {cv_results[latent_dim]['time']['mean_accuracy']:.1f}% ± {cv_results[latent_dim]['time']['std_accuracy']:.1f}%")
    else:
        print("✓ No existing cross-validation results found")
# Out:
# === CROSS-VALIDATION EXPERIMENTS (5 trials) ===
#
# --- LATENT DIMENSION: 8 ---
#
# SUBJECT SPLIT:
#
# === Curvature Model Trial 1/5 (subject split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15053001sub1', '16100101', '15111101', '15081202sub2', '14101601', '14092201', '14091102', '15053001sub2', '15052902', '14091701', '16101401', '16102002', '15040901', '16100801']
#   Test subjects (3): ['15080601', '15012001', '16100601']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Loss: 1.0666 (Class: 1.0262, Recon: 0.4046)
#   Train Acc: 54.17%, Test Acc: 55.56%
#   Curvature: mean=38.0859, std=103.5866
# Epoch 20/100:
#   Train Loss: 1.0332 (Class: 0.9994, Recon: 0.3380)
#   Train Acc: 55.42%, Test Acc: 53.70%
#   Curvature: mean=33.6569, std=89.1882
# Epoch 30/100:
#   Train Loss: 1.0047 (Class: 0.9721, Recon: 0.3256)
#   Train Acc: 56.67%, Test Acc: 55.56%
#   Curvature: mean=32.2119, std=113.6072
# Epoch 40/100:
#   Train Loss: 1.0137 (Class: 0.9833, Recon: 0.3040)
#   Train Acc: 55.83%, Test Acc: 55.56%
#   Curvature: mean=30.2050, std=85.8016
# Epoch 50/100:
#   Train Loss: 1.0124 (Class: 0.9811, Recon: 0.3128)
#   Train Acc: 54.17%, Test Acc: 55.56%
#   Curvature: mean=28.5105, std=76.1380
# Epoch 60/100:
#   Train Loss: 1.0434 (Class: 1.0156, Recon: 0.2782)
#   Train Acc: 54.58%, Test Acc: 55.56%
#   Curvature: mean=30.2948, std=85.2905
# Epoch 70/100:
#   Train Loss: 0.9897 (Class: 0.9609, Recon: 0.2880)
#   Train Acc: 55.00%, Test Acc: 55.56%
#   Curvature: mean=30.1799, std=84.9131
# Epoch 80/100:
#   Train Loss: 1.0210 (Class: 0.9927, Recon: 0.2837)
#   Train Acc: 55.00%, Test Acc: 55.56%
#   Curvature: mean=30.4804, std=84.7379
# Epoch 90/100:
#   Train Loss: 1.0058 (Class: 0.9761, Recon: 0.2978)
#   Train Acc: 57.08%, Test Acc: 55.56%
#   Curvature: mean=29.1298, std=81.2862
# Epoch 100/100:
#   Train Loss: 1.0216 (Class: 0.9907, Recon: 0.3093)
#   Train Acc: 55.00%, Test Acc: 55.56%
#   Curvature: mean=30.0515, std=86.3193
#
# Final Results:
#   Train Accuracy: 55.0%
#   Test Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
#
# === Curvature Model Trial 2/5 (subject split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15053001sub2', '16102002', '16100101', '14091701', '16100801', '14092201', '15111101', '15040901', '15053001sub1', '16101401', '16100601', '15012001', '15080601', '15052902']
#   Test subjects (3): ['14101601', '14091102', '15081202sub2']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Loss: 1.0739 (Class: 1.0332, Recon: 0.4069)
#   Train Acc: 54.58%, Test Acc: 46.30%
#   Curvature: mean=61.2916, std=254.2357
# Epoch 20/100:
#   Train Loss: 1.0097 (Class: 0.9810, Recon: 0.2870)
#   Train Acc: 55.83%, Test Acc: 48.15%
#   Curvature: mean=60.2784, std=257.5482
# Epoch 30/100:
#   Train Loss: 1.0174 (Class: 0.9880, Recon: 0.2936)
#   Train Acc: 55.42%, Test Acc: 50.00%
#   Curvature: mean=56.0925, std=253.6888
# Epoch 40/100:
#   Train Loss: 1.0153 (Class: 0.9855, Recon: 0.2979)
#   Train Acc: 57.92%, Test Acc: 46.30%
#   Curvature: mean=55.5310, std=246.8185
# Epoch 50/100:
#   Train Loss: 1.0176 (Class: 0.9897, Recon: 0.2798)
#   Train Acc: 53.75%, Test Acc: 46.30%
#   Curvature: mean=56.9822, std=251.9916
# Epoch 60/100:
#   Train Loss: 1.0229 (Class: 0.9967, Recon: 0.2617)
#   Train Acc: 54.17%, Test Acc: 44.44%
#   Curvature: mean=55.4251, std=262.6837
# Epoch 70/100:
#   Train Loss: 1.0151 (Class: 0.9856, Recon: 0.2952)
#   Train Acc: 55.42%, Test Acc: 46.30%
#   Curvature: mean=56.4481, std=259.3446
# Epoch 80/100:
#   Train Loss: 1.0220 (Class: 0.9949, Recon: 0.2702)
#   Train Acc: 57.50%, Test Acc: 42.59%
#   Curvature: mean=56.9088, std=253.0902
# Epoch 90/100:
#   Train Loss: 1.0081 (Class: 0.9813, Recon: 0.2676)
#   Train Acc: 55.00%, Test Acc: 42.59%
#   Curvature: mean=56.7838, std=250.6688
# Epoch 100/100:
#   Train Loss: 1.0173 (Class: 0.9888, Recon: 0.2858)
#   Train Acc: 55.00%, Test Acc: 42.59%
#   Curvature: mean=58.7197, std=262.6059
#
# Final Results:
#   Train Accuracy: 55.0%
#   Test Accuracy: 42.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.52      0.77      0.62        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.43        54
#    macro avg       0.17      0.26      0.21        54
# weighted avg       0.29      0.43      0.35        54
#
#
# === Curvature Model Trial 3/5 (subject split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['16101401', '14091102', '15053001sub1', '16100801', '14091701', '15081202sub2', '16102002', '15052902', '15080601', '15053001sub2', '16100101', '14101601', '15012001', '15040901']
#   Test subjects (3): ['15111101', '16100601', '14092201']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Loss: 1.0710 (Class: 1.0358, Recon: 0.3513)
#   Train Acc: 52.92%, Test Acc: 48.15%
#   Curvature: mean=45.0018, std=146.2478
# Epoch 20/100:
#   Train Loss: 0.9932 (Class: 0.9578, Recon: 0.3533)
#   Train Acc: 57.08%, Test Acc: 35.19%
#   Curvature: mean=45.0625, std=220.4375
# Epoch 30/100:
#   Train Loss: 1.0195 (Class: 0.9878, Recon: 0.3168)
#   Train Acc: 55.42%, Test Acc: 44.44%
#   Curvature: mean=45.0268, std=184.8028
# Epoch 40/100:
#   Train Loss: 1.0570 (Class: 1.0234, Recon: 0.3361)
#   Train Acc: 55.00%, Test Acc: 48.15%
#   Curvature: mean=41.8029, std=180.5476
# Epoch 50/100:
#   Train Loss: 1.0209 (Class: 0.9890, Recon: 0.3194)
#   Train Acc: 54.17%, Test Acc: 51.85%
#   Curvature: mean=43.9140, std=180.3330
# Epoch 60/100:
#   Train Loss: 1.0416 (Class: 1.0091, Recon: 0.3248)
#   Train Acc: 54.17%, Test Acc: 44.44%
#   Curvature: mean=43.5070, std=207.5703
# Epoch 70/100:
#   Train Loss: 1.0091 (Class: 0.9775, Recon: 0.3160)
#   Train Acc: 54.17%, Test Acc: 46.30%
#   Curvature: mean=43.3983, std=184.6936
# Epoch 80/100:
#   Train Loss: 1.0166 (Class: 0.9859, Recon: 0.3074)
#   Train Acc: 57.50%, Test Acc: 50.00%
#   Curvature: mean=43.3820, std=182.4681
# Epoch 90/100:
#   Train Loss: 1.0318 (Class: 1.0009, Recon: 0.3089)
#   Train Acc: 56.25%, Test Acc: 50.00%
#   Curvature: mean=41.9427, std=169.5186
# Epoch 100/100:
#   Train Loss: 1.0442 (Class: 1.0148, Recon: 0.2938)
#   Train Acc: 56.25%, Test Acc: 48.15%
#   Curvature: mean=44.0397, std=201.1329
#
# Final Results:
#   Train Accuracy: 56.2%
#   Test Accuracy: 48.1%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.55      0.80      0.65        30
#       Improv       0.20      0.17      0.18        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.48        54
#    macro avg       0.25      0.32      0.28        54
# weighted avg       0.35      0.48      0.40        54
#
#
# === Curvature Model Trial 4/5 (subject split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['14092201', '16100801', '15053001sub2', '15012001', '14091701', '15081202sub2', '15052902', '15053001sub1', '16100601', '15080601', '16102002', '15040901', '15111101', '16100101']
#   Test subjects (3): ['16101401', '14091102', '14101601']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Loss: 1.0351 (Class: 0.9929, Recon: 0.4222)
#   Train Acc: 55.00%, Test Acc: 55.56%
#   Curvature: mean=49.4614, std=120.2869
# Epoch 20/100:
#   Train Loss: 1.0075 (Class: 0.9724, Recon: 0.3504)
#   Train Acc: 55.00%, Test Acc: 57.41%
#   Curvature: mean=49.7066, std=132.6377
# Epoch 30/100:
#   Train Loss: 0.9774 (Class: 0.9487, Recon: 0.2869)
#   Train Acc: 56.25%, Test Acc: 55.56%
#   Curvature: mean=44.1473, std=120.4301
# Epoch 40/100:
#   Train Loss: 0.9129 (Class: 0.8851, Recon: 0.2773)
#   Train Acc: 62.50%, Test Acc: 55.56%
#   Curvature: mean=47.2666, std=130.2309
# Epoch 50/100:
#   Train Loss: 0.9494 (Class: 0.9209, Recon: 0.2858)
#   Train Acc: 60.00%, Test Acc: 55.56%
#   Curvature: mean=47.1518, std=134.6232
# Epoch 60/100:
#   Train Loss: 0.9250 (Class: 0.8933, Recon: 0.3175)
#   Train Acc: 59.17%, Test Acc: 53.70%
#   Curvature: mean=46.1276, std=132.4055
# Epoch 70/100:
#   Train Loss: 0.9359 (Class: 0.9084, Recon: 0.2757)
#   Train Acc: 58.75%, Test Acc: 55.56%
#   Curvature: mean=48.3609, std=140.8182
# Epoch 80/100:
#   Train Loss: 0.9513 (Class: 0.9202, Recon: 0.3105)
#   Train Acc: 57.50%, Test Acc: 55.56%
#   Curvature: mean=46.9911, std=145.5455
# Epoch 90/100:
#   Train Loss: 0.9639 (Class: 0.9367, Recon: 0.2719)
#   Train Acc: 57.08%, Test Acc: 53.70%
#   Curvature: mean=47.0101, std=137.9295
# Epoch 100/100:
#   Train Loss: 0.9626 (Class: 0.9329, Recon: 0.2972)
#   Train Acc: 58.75%, Test Acc: 55.56%
#   Curvature: mean=46.9109, std=132.1239
#
# Final Results:
#   Train Accuracy: 58.8%
#   Test Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      1.00      0.71        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.19      0.33      0.24        54
# weighted avg       0.31      0.56      0.40        54
#
#
# === Curvature Model Trial 5/5 (subject split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15111101', '16102002', '14091102', '16100801', '14101601', '15053001sub1', '16100101', '15080601', '14092201', '15040901', '16101401', '15052902', '15081202sub2', '16100601']
#   Test subjects (3): ['15012001', '14091701', '15053001sub2']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Loss: 1.0637 (Class: 1.0229, Recon: 0.4074)
#   Train Acc: 55.42%, Test Acc: 55.56%
#   Curvature: mean=47.0265, std=127.2424
# Epoch 20/100:
#   Train Loss: 1.0684 (Class: 1.0303, Recon: 0.3813)
#   Train Acc: 54.17%, Test Acc: 53.70%
#   Curvature: mean=47.0055, std=130.8866
# Epoch 30/100:
#   Train Loss: 1.0432 (Class: 1.0094, Recon: 0.3383)
#   Train Acc: 55.83%, Test Acc: 55.56%
#   Curvature: mean=47.3092, std=126.8653
# Epoch 40/100:
#   Train Loss: 1.0303 (Class: 0.9988, Recon: 0.3153)
#   Train Acc: 55.00%, Test Acc: 53.70%
#   Curvature: mean=47.8705, std=154.0588
# Epoch 50/100:
#   Train Loss: 1.0088 (Class: 0.9799, Recon: 0.2883)
#   Train Acc: 57.92%, Test Acc: 53.70%
#   Curvature: mean=48.0345, std=131.2531
# Epoch 60/100:
#   Train Loss: 1.0723 (Class: 1.0420, Recon: 0.3034)
#   Train Acc: 55.42%, Test Acc: 51.85%
#   Curvature: mean=47.8573, std=131.8475
# Epoch 70/100:
#   Train Loss: 1.0495 (Class: 1.0194, Recon: 0.3008)
#   Train Acc: 55.42%, Test Acc: 53.70%
#   Curvature: mean=46.6782, std=129.1628
# Epoch 80/100:
#   Train Loss: 1.0519 (Class: 1.0209, Recon: 0.3098)
#   Train Acc: 54.17%, Test Acc: 53.70%
#   Curvature: mean=47.3875, std=134.8051
# Epoch 90/100:
#   Train Loss: 1.0137 (Class: 0.9826, Recon: 0.3108)
#   Train Acc: 55.42%, Test Acc: 55.56%
#   Curvature: mean=46.5716, std=133.3829
# Epoch 100/100:
#   Train Loss: 1.0680 (Class: 1.0373, Recon: 0.3075)
#   Train Acc: 55.42%, Test Acc: 53.70%
#   Curvature: mean=47.8567, std=133.5283
#
# Final Results:
#   Train Accuracy: 55.4%
#   Test Accuracy: 53.7%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.55      0.97      0.70        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.54        54
#    macro avg       0.18      0.32      0.23        54
# weighted avg       0.30      0.54      0.39        54
#
# Results saved to: /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/curvature_results/curvature_subject_8d_cv_results.pkl
#
# === Curvature Results (subject split, 8D) ===
# Accuracy: 51.1% ± 5.1%
#
# TIME SPLIT:
#
# === Curvature Model Trial 1/5 (time split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Loss: 1.0657 (Class: 1.0252, Recon: 0.4050)
#   Train Acc: 57.14%, Test Acc: 50.00%
#   Curvature: mean=42.6192, std=134.0685
# Epoch 20/100:
#   Train Loss: 1.0493 (Class: 1.0115, Recon: 0.3782)
#   Train Acc: 55.36%, Test Acc: 50.00%
#   Curvature: mean=45.7031, std=183.2423
# Epoch 30/100:
#   Train Loss: 0.9910 (Class: 0.9575, Recon: 0.3349)
#   Train Acc: 56.25%, Test Acc: 50.00%
#   Curvature: mean=44.6872, std=170.4677
# Epoch 40/100:
#   Train Loss: 1.0131 (Class: 0.9772, Recon: 0.3597)
#   Train Acc: 55.36%, Test Acc: 50.00%
#   Curvature: mean=46.9309, std=199.7737
# Epoch 50/100:
#   Train Loss: 1.0054 (Class: 0.9705, Recon: 0.3492)
#   Train Acc: 53.57%, Test Acc: 50.00%
#   Curvature: mean=46.2333, std=166.3434
# Epoch 60/100:
#   Train Loss: 0.9807 (Class: 0.9491, Recon: 0.3155)
#   Train Acc: 58.93%, Test Acc: 50.00%
#   Curvature: mean=44.6155, std=176.3769
# Epoch 70/100:
#   Train Loss: 0.9763 (Class: 0.9419, Recon: 0.3434)
#   Train Acc: 57.59%, Test Acc: 50.00%
#   Curvature: mean=47.1675, std=220.3411
# Epoch 80/100:
#   Train Loss: 1.0144 (Class: 0.9796, Recon: 0.3476)
#   Train Acc: 56.70%, Test Acc: 50.00%
#   Curvature: mean=45.5702, std=166.1452
# Epoch 90/100:
#   Train Loss: 1.0211 (Class: 0.9855, Recon: 0.3559)
#   Train Acc: 55.80%, Test Acc: 50.00%
#   Curvature: mean=46.0441, std=162.1415
# Epoch 100/100:
#   Train Loss: 1.0549 (Class: 1.0203, Recon: 0.3457)
#   Train Acc: 55.36%, Test Acc: 50.00%
#   Curvature: mean=47.0928, std=178.1432
#
# Final Results:
#   Train Accuracy: 55.4%
#   Test Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
#
# === Curvature Model Trial 2/5 (time split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Loss: 1.0257 (Class: 0.9865, Recon: 0.3926)
#   Train Acc: 55.36%, Test Acc: 50.00%
#   Curvature: mean=42.4026, std=154.1114
# Epoch 20/100:
#   Train Loss: 1.0224 (Class: 0.9887, Recon: 0.3371)
#   Train Acc: 55.80%, Test Acc: 50.00%
#   Curvature: mean=48.1325, std=198.8322
# Epoch 30/100:
#   Train Loss: 1.0246 (Class: 0.9901, Recon: 0.3450)
#   Train Acc: 55.36%, Test Acc: 51.47%
#   Curvature: mean=45.8276, std=235.7059
# Epoch 40/100:
#   Train Loss: 1.0156 (Class: 0.9811, Recon: 0.3450)
#   Train Acc: 56.70%, Test Acc: 50.00%
#   Curvature: mean=48.6039, std=196.5893
# Epoch 50/100:
#   Train Loss: 1.0046 (Class: 0.9712, Recon: 0.3346)
#   Train Acc: 56.70%, Test Acc: 50.00%
#   Curvature: mean=46.3929, std=164.7688
# Epoch 60/100:
#   Train Loss: 1.0338 (Class: 0.9977, Recon: 0.3611)
#   Train Acc: 56.70%, Test Acc: 50.00%
#   Curvature: mean=45.6343, std=177.5319
# Epoch 70/100:
#   Train Loss: 1.0059 (Class: 0.9712, Recon: 0.3478)
#   Train Acc: 57.14%, Test Acc: 50.00%
#   Curvature: mean=45.6285, std=178.6407
# Epoch 80/100:
#   Train Loss: 0.9750 (Class: 0.9417, Recon: 0.3330)
#   Train Acc: 59.82%, Test Acc: 50.00%
#   Curvature: mean=49.3214, std=221.1438
# Epoch 90/100:
#   Train Loss: 1.0214 (Class: 0.9855, Recon: 0.3585)
#   Train Acc: 57.14%, Test Acc: 50.00%
#   Curvature: mean=47.3286, std=187.0146
# Epoch 100/100:
#   Train Loss: 1.0253 (Class: 0.9911, Recon: 0.3420)
#   Train Acc: 55.36%, Test Acc: 50.00%
#   Curvature: mean=48.0985, std=202.5854
#
# Final Results:
#   Train Accuracy: 55.4%
#   Test Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
#
# === Curvature Model Trial 3/5 (time split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Loss: 1.0366 (Class: 0.9960, Recon: 0.4063)
#   Train Acc: 57.59%, Test Acc: 50.00%
#   Curvature: mean=45.0947, std=114.1086
# Epoch 20/100:
#   Train Loss: 1.0003 (Class: 0.9651, Recon: 0.3523)
#   Train Acc: 57.59%, Test Acc: 50.00%
#   Curvature: mean=42.4324, std=134.0573
# Epoch 30/100:
#   Train Loss: 0.9826 (Class: 0.9515, Recon: 0.3106)
#   Train Acc: 58.93%, Test Acc: 50.00%
#   Curvature: mean=40.9296, std=122.5832
# Epoch 40/100:
#   Train Loss: 0.9788 (Class: 0.9470, Recon: 0.3176)
#   Train Acc: 55.36%, Test Acc: 50.00%
#   Curvature: mean=39.7075, std=119.1903
# Epoch 50/100:
#   Train Loss: 1.0195 (Class: 0.9830, Recon: 0.3655)
#   Train Acc: 55.80%, Test Acc: 50.00%
#   Curvature: mean=39.8334, std=121.2762
# Epoch 60/100:
#   Train Loss: 0.9985 (Class: 0.9658, Recon: 0.3267)
#   Train Acc: 54.91%, Test Acc: 50.00%
#   Curvature: mean=39.3705, std=116.7382
# Epoch 70/100:
#   Train Loss: 1.0053 (Class: 0.9717, Recon: 0.3358)
#   Train Acc: 57.59%, Test Acc: 50.00%
#   Curvature: mean=38.8441, std=111.2787
# Epoch 80/100:
#   Train Loss: 0.9892 (Class: 0.9573, Recon: 0.3188)
#   Train Acc: 55.36%, Test Acc: 50.00%
#   Curvature: mean=39.9103, std=115.8993
# Epoch 90/100:
#   Train Loss: 1.0040 (Class: 0.9734, Recon: 0.3067)
#   Train Acc: 56.25%, Test Acc: 50.00%
#   Curvature: mean=40.9987, std=128.8270
# Epoch 100/100:
#   Train Loss: 0.9838 (Class: 0.9527, Recon: 0.3106)
#   Train Acc: 56.70%, Test Acc: 50.00%
#   Curvature: mean=40.8158, std=123.7128
#
# Final Results:
#   Train Accuracy: 56.7%
#   Test Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
#
# === Curvature Model Trial 4/5 (time split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Loss: 1.0271 (Class: 0.9869, Recon: 0.4014)
#   Train Acc: 55.80%, Test Acc: 48.53%
#   Curvature: mean=46.2099, std=120.8075
# Epoch 20/100:
#   Train Loss: 1.0177 (Class: 0.9826, Recon: 0.3506)
#   Train Acc: 54.02%, Test Acc: 50.00%
#   Curvature: mean=42.3697, std=119.8914
# Epoch 30/100:
#   Train Loss: 0.9648 (Class: 0.9341, Recon: 0.3069)
#   Train Acc: 58.04%, Test Acc: 50.00%
#   Curvature: mean=43.2098, std=115.4683
# Epoch 40/100:
#   Train Loss: 0.9903 (Class: 0.9576, Recon: 0.3269)
#   Train Acc: 55.80%, Test Acc: 50.00%
#   Curvature: mean=44.1183, std=121.6834
# Epoch 50/100:
#   Train Loss: 0.9714 (Class: 0.9418, Recon: 0.2957)
#   Train Acc: 59.82%, Test Acc: 48.53%
#   Curvature: mean=44.8119, std=120.8706
# Epoch 60/100:
#   Train Loss: 0.9978 (Class: 0.9641, Recon: 0.3375)
#   Train Acc: 55.36%, Test Acc: 48.53%
#   Curvature: mean=44.5761, std=124.4464
# Epoch 70/100:
#   Train Loss: 0.9928 (Class: 0.9601, Recon: 0.3270)
#   Train Acc: 55.80%, Test Acc: 48.53%
#   Curvature: mean=43.7192, std=117.2400
# Epoch 80/100:
#   Train Loss: 1.0174 (Class: 0.9842, Recon: 0.3320)
#   Train Acc: 55.80%, Test Acc: 50.00%
#   Curvature: mean=44.8821, std=134.2528
# Epoch 90/100:
#   Train Loss: 0.9775 (Class: 0.9441, Recon: 0.3339)
#   Train Acc: 56.25%, Test Acc: 48.53%
#   Curvature: mean=44.0219, std=122.3437
# Epoch 100/100:
#   Train Loss: 0.9871 (Class: 0.9531, Recon: 0.3408)
#   Train Acc: 61.16%, Test Acc: 50.00%
#   Curvature: mean=44.5172, std=124.5420
#
# Final Results:
#   Train Accuracy: 61.2%
#   Test Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.51      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.34        68
#
#
# === Curvature Model Trial 5/5 (time split, 8D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Loss: 1.1004 (Class: 1.0564, Recon: 0.4404)
#   Train Acc: 52.23%, Test Acc: 50.00%
#   Curvature: mean=48.4182, std=153.0573
# Epoch 20/100:
#   Train Loss: 1.0078 (Class: 0.9739, Recon: 0.3393)
#   Train Acc: 55.80%, Test Acc: 50.00%
#   Curvature: mean=45.5260, std=176.6023
# Epoch 30/100:
#   Train Loss: 0.9912 (Class: 0.9549, Recon: 0.3622)
#   Train Acc: 52.68%, Test Acc: 50.00%
#   Curvature: mean=43.5806, std=130.9368
# Epoch 40/100:
#   Train Loss: 0.9926 (Class: 0.9582, Recon: 0.3438)
#   Train Acc: 58.48%, Test Acc: 50.00%
#   Curvature: mean=42.1660, std=141.8326
# Epoch 50/100:
#   Train Loss: 1.0012 (Class: 0.9709, Recon: 0.3024)
#   Train Acc: 55.36%, Test Acc: 50.00%
#   Curvature: mean=44.2462, std=136.9226
# Epoch 60/100:
#   Train Loss: 1.0130 (Class: 0.9803, Recon: 0.3269)
#   Train Acc: 57.59%, Test Acc: 50.00%
#   Curvature: mean=42.7543, std=140.9106
# Epoch 70/100:
#   Train Loss: 0.9770 (Class: 0.9421, Recon: 0.3492)
#   Train Acc: 58.04%, Test Acc: 50.00%
#   Curvature: mean=43.2766, std=139.4014
# Epoch 80/100:
#   Train Loss: 1.0066 (Class: 0.9725, Recon: 0.3403)
#   Train Acc: 50.89%, Test Acc: 50.00%
#   Curvature: mean=41.9945, std=135.6536
# Epoch 90/100:
#   Train Loss: 0.9980 (Class: 0.9628, Recon: 0.3523)
#   Train Acc: 56.70%, Test Acc: 50.00%
#   Curvature: mean=41.3021, std=133.9917
# Epoch 100/100:
#   Train Loss: 1.0097 (Class: 0.9760, Recon: 0.3375)
#   Train Acc: 57.14%, Test Acc: 50.00%
#   Curvature: mean=42.1279, std=136.3820
#
# Final Results:
#   Train Accuracy: 57.1%
#   Test Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.50      1.00      0.67        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.00      0.00      0.00        17
#
#     accuracy                           0.50        68
#    macro avg       0.17      0.33      0.22        68
# weighted avg       0.25      0.50      0.33        68
#
# Results saved to: /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/curvature_results/curvature_time_8d_cv_results.pkl
#
# === Curvature Results (time split, 8D) ===
# Accuracy: 50.0% ± 0.0%
#
# --- LATENT DIMENSION: 48 ---
#
# SUBJECT SPLIT:
#
# === Curvature Model Trial 1/5 (subject split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15053001sub1', '16100101', '15111101', '15081202sub2', '14101601', '14092201', '14091102', '15053001sub2', '15052902', '14091701', '16101401', '16102002', '15040901', '16100801']
#   Test subjects (3): ['15080601', '15012001', '16100601']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Loss: 0.9997 (Class: 0.9631, Recon: 0.3651)
#   Train Acc: 52.92%, Test Acc: 40.74%
#   Curvature: mean=12.1962, std=29.6104
# Epoch 20/100:
#   Train Loss: 0.8867 (Class: 0.8574, Recon: 0.2932)
#   Train Acc: 58.75%, Test Acc: 40.74%
#   Curvature: mean=10.2301, std=21.6656
# Epoch 30/100:
#   Train Loss: 0.7195 (Class: 0.6944, Recon: 0.2512)
#   Train Acc: 70.83%, Test Acc: 40.74%
#   Curvature: mean=8.7639, std=16.9321
# Epoch 40/100:
#   Train Loss: 0.6712 (Class: 0.6463, Recon: 0.2488)
#   Train Acc: 71.67%, Test Acc: 38.89%
#   Curvature: mean=8.3687, std=15.3291
# Epoch 50/100:
#   Train Loss: 0.6112 (Class: 0.5883, Recon: 0.2296)
#   Train Acc: 75.00%, Test Acc: 44.44%
#   Curvature: mean=8.2247, std=15.1042
# Epoch 60/100:
#   Train Loss: 0.6285 (Class: 0.6046, Recon: 0.2387)
#   Train Acc: 72.92%, Test Acc: 37.04%
#   Curvature: mean=8.3514, std=15.1907
# Epoch 70/100:
#   Train Loss: 0.6392 (Class: 0.6177, Recon: 0.2154)
#   Train Acc: 73.75%, Test Acc: 33.33%
#   Curvature: mean=8.1877, std=14.9697
# Epoch 80/100:
#   Train Loss: 0.6016 (Class: 0.5771, Recon: 0.2453)
#   Train Acc: 75.42%, Test Acc: 37.04%
#   Curvature: mean=8.3023, std=14.8254
# Epoch 90/100:
#   Train Loss: 0.5960 (Class: 0.5729, Recon: 0.2307)
#   Train Acc: 75.00%, Test Acc: 40.74%
#   Curvature: mean=8.1086, std=14.5238
# Epoch 100/100:
#   Train Loss: 0.6206 (Class: 0.5969, Recon: 0.2375)
#   Train Acc: 74.58%, Test Acc: 38.89%
#   Curvature: mean=8.2584, std=14.7729
#
# Final Results:
#   Train Accuracy: 74.6%
#   Test Accuracy: 38.9%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.60      0.40      0.48        30
#       Improv       0.26      0.75      0.39        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.39        54
#    macro avg       0.29      0.38      0.29        54
# weighted avg       0.39      0.39      0.35        54
#
#
# === Curvature Model Trial 2/5 (subject split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15053001sub2', '16102002', '16100101', '14091701', '16100801', '14092201', '15111101', '15040901', '15053001sub1', '16101401', '16100601', '15012001', '15080601', '15052902']
#   Test subjects (3): ['14101601', '14091102', '15081202sub2']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Loss: 1.0177 (Class: 0.9875, Recon: 0.3019)
#   Train Acc: 53.75%, Test Acc: 38.89%
#   Curvature: mean=28.0032, std=90.0768
# Epoch 20/100:
#   Train Loss: 0.9024 (Class: 0.8783, Recon: 0.2412)
#   Train Acc: 58.75%, Test Acc: 25.93%
#   Curvature: mean=29.3290, std=70.8134
# Epoch 30/100:
#   Train Loss: 0.8794 (Class: 0.8519, Recon: 0.2743)
#   Train Acc: 59.17%, Test Acc: 31.48%
#   Curvature: mean=26.3807, std=71.5493
# Epoch 40/100:
#   Train Loss: 0.8571 (Class: 0.8334, Recon: 0.2369)
#   Train Acc: 61.67%, Test Acc: 24.07%
#   Curvature: mean=25.4918, std=63.9288
# Epoch 50/100:
#   Train Loss: 0.8687 (Class: 0.8426, Recon: 0.2613)
#   Train Acc: 61.25%, Test Acc: 24.07%
#   Curvature: mean=25.7663, std=66.3207
# Epoch 60/100:
#   Train Loss: 0.8444 (Class: 0.8211, Recon: 0.2329)
#   Train Acc: 62.08%, Test Acc: 22.22%
#   Curvature: mean=25.2365, std=58.3404
# Epoch 70/100:
#   Train Loss: 0.8375 (Class: 0.8121, Recon: 0.2545)
#   Train Acc: 64.58%, Test Acc: 27.78%
#   Curvature: mean=25.5158, std=69.0488
# Epoch 80/100:
#   Train Loss: 0.8302 (Class: 0.8056, Recon: 0.2458)
#   Train Acc: 63.75%, Test Acc: 22.22%
#   Curvature: mean=25.5028, std=66.0949
# Epoch 90/100:
#   Train Loss: 0.8220 (Class: 0.8000, Recon: 0.2194)
#   Train Acc: 65.00%, Test Acc: 24.07%
#   Curvature: mean=26.1634, std=66.3510
# Epoch 100/100:
#   Train Loss: 0.8173 (Class: 0.7964, Recon: 0.2091)
#   Train Acc: 63.33%, Test Acc: 27.78%
#   Curvature: mean=26.2922, std=62.2909
#
# Final Results:
#   Train Accuracy: 63.3%
#   Test Accuracy: 27.8%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.48      0.40      0.44        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.11      0.25      0.15        12
#
#     accuracy                           0.28        54
#    macro avg       0.20      0.22      0.20        54
# weighted avg       0.29      0.28      0.28        54
#
#
# === Curvature Model Trial 3/5 (subject split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['16101401', '14091102', '15053001sub1', '16100801', '14091701', '15081202sub2', '16102002', '15052902', '15080601', '15053001sub2', '16100101', '14101601', '15012001', '15040901']
#   Test subjects (3): ['15111101', '16100601', '14092201']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Loss: 1.0210 (Class: 0.9873, Recon: 0.3367)
#   Train Acc: 55.42%, Test Acc: 51.85%
#   Curvature: mean=21.1548, std=54.5013
# Epoch 20/100:
#   Train Loss: 0.8792 (Class: 0.8492, Recon: 0.3000)
#   Train Acc: 60.83%, Test Acc: 40.74%
#   Curvature: mean=15.5774, std=34.9352
# Epoch 30/100:
#   Train Loss: 0.7627 (Class: 0.7326, Recon: 0.3011)
#   Train Acc: 70.42%, Test Acc: 44.44%
#   Curvature: mean=14.2396, std=31.3712
# Epoch 40/100:
#   Train Loss: 0.6378 (Class: 0.6129, Recon: 0.2492)
#   Train Acc: 75.42%, Test Acc: 29.63%
#   Curvature: mean=13.4141, std=26.1900
# Epoch 50/100:
#   Train Loss: 0.5176 (Class: 0.4952, Recon: 0.2237)
#   Train Acc: 78.75%, Test Acc: 29.63%
#   Curvature: mean=13.0126, std=23.8708
# Epoch 60/100:
#   Train Loss: 0.5326 (Class: 0.5084, Recon: 0.2421)
#   Train Acc: 81.25%, Test Acc: 38.89%
#   Curvature: mean=13.0422, std=23.8607
# Epoch 70/100:
#   Train Loss: 0.5802 (Class: 0.5567, Recon: 0.2355)
#   Train Acc: 75.83%, Test Acc: 33.33%
#   Curvature: mean=13.1654, std=23.9403
# Epoch 80/100:
#   Train Loss: 0.4931 (Class: 0.4713, Recon: 0.2176)
#   Train Acc: 82.92%, Test Acc: 37.04%
#   Curvature: mean=13.4383, std=24.1784
# Epoch 90/100:
#   Train Loss: 0.5168 (Class: 0.4977, Recon: 0.1903)
#   Train Acc: 78.33%, Test Acc: 38.89%
#   Curvature: mean=13.5976, std=24.8610
# Epoch 100/100:
#   Train Loss: 0.5669 (Class: 0.5471, Recon: 0.1981)
#   Train Acc: 77.08%, Test Acc: 40.74%
#   Curvature: mean=13.1465, std=24.0958
#
# Final Results:
#   Train Accuracy: 77.1%
#   Test Accuracy: 40.7%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.51      0.63      0.57        30
#       Improv       0.12      0.08      0.10        12
#        Scale       0.22      0.17      0.19        12
#
#     accuracy                           0.41        54
#    macro avg       0.29      0.29      0.29        54
# weighted avg       0.36      0.41      0.38        54
#
#
# === Curvature Model Trial 4/5 (subject split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['14092201', '16100801', '15053001sub2', '15012001', '14091701', '15081202sub2', '15052902', '15053001sub1', '16100601', '15080601', '16102002', '15040901', '15111101', '16100101']
#   Test subjects (3): ['16101401', '14091102', '14101601']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Loss: 1.0275 (Class: 0.9959, Recon: 0.3158)
#   Train Acc: 52.08%, Test Acc: 51.85%
#   Curvature: mean=23.5711, std=64.1408
# Epoch 20/100:
#   Train Loss: 0.9317 (Class: 0.9057, Recon: 0.2605)
#   Train Acc: 58.75%, Test Acc: 57.41%
#   Curvature: mean=24.6594, std=79.9252
# Epoch 30/100:
#   Train Loss: 0.9324 (Class: 0.9075, Recon: 0.2485)
#   Train Acc: 56.67%, Test Acc: 57.41%
#   Curvature: mean=22.9471, std=55.9120
# Epoch 40/100:
#   Train Loss: 0.8916 (Class: 0.8675, Recon: 0.2406)
#   Train Acc: 59.17%, Test Acc: 57.41%
#   Curvature: mean=22.4873, std=60.5220
# Epoch 50/100:
#   Train Loss: 0.8876 (Class: 0.8652, Recon: 0.2239)
#   Train Acc: 58.75%, Test Acc: 57.41%
#   Curvature: mean=23.0649, std=61.2638
# Epoch 60/100:
#   Train Loss: 0.8929 (Class: 0.8689, Recon: 0.2407)
#   Train Acc: 60.42%, Test Acc: 55.56%
#   Curvature: mean=22.4802, std=61.7398
# Epoch 70/100:
#   Train Loss: 0.8834 (Class: 0.8605, Recon: 0.2289)
#   Train Acc: 59.58%, Test Acc: 55.56%
#   Curvature: mean=23.6738, std=65.8135
# Epoch 80/100:
#   Train Loss: 0.8809 (Class: 0.8558, Recon: 0.2506)
#   Train Acc: 60.00%, Test Acc: 57.41%
#   Curvature: mean=22.5732, std=58.4187
# Epoch 90/100:
#   Train Loss: 0.9077 (Class: 0.8844, Recon: 0.2329)
#   Train Acc: 60.83%, Test Acc: 55.56%
#   Curvature: mean=23.4968, std=68.8685
# Epoch 100/100:
#   Train Loss: 0.9007 (Class: 0.8768, Recon: 0.2388)
#   Train Acc: 57.50%, Test Acc: 55.56%
#   Curvature: mean=22.4934, std=64.7804
#
# Final Results:
#   Train Accuracy: 57.5%
#   Test Accuracy: 55.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.62      0.77      0.69        30
#       Improv       0.41      0.58      0.48        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.56        54
#    macro avg       0.34      0.45      0.39        54
# weighted avg       0.44      0.56      0.49        54
#
#
# === Curvature Model Trial 5/5 (subject split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Subject split:
#   Train subjects (14): ['15111101', '16102002', '14091102', '16100801', '14101601', '15053001sub1', '16100101', '15080601', '14092201', '15040901', '16101401', '15052902', '15081202sub2', '16100601']
#   Test subjects (3): ['15012001', '14091701', '15053001sub2']
#
# Split results:
#   Train: 252 intervals
#   Test: 54 intervals
# Epoch 10/100:
#   Train Loss: 0.9787 (Class: 0.9486, Recon: 0.3010)
#   Train Acc: 57.92%, Test Acc: 53.70%
#   Curvature: mean=26.8755, std=60.5482
# Epoch 20/100:
#   Train Loss: 0.9182 (Class: 0.8915, Recon: 0.2670)
#   Train Acc: 60.42%, Test Acc: 46.30%
#   Curvature: mean=27.0995, std=55.3474
# Epoch 30/100:
#   Train Loss: 0.8320 (Class: 0.8086, Recon: 0.2347)
#   Train Acc: 64.58%, Test Acc: 42.59%
#   Curvature: mean=23.6230, std=45.7608
# Epoch 40/100:
#   Train Loss: 0.7671 (Class: 0.7400, Recon: 0.2704)
#   Train Acc: 67.50%, Test Acc: 48.15%
#   Curvature: mean=19.4640, std=43.3265
# Epoch 50/100:
#   Train Loss: 0.6957 (Class: 0.6718, Recon: 0.2389)
#   Train Acc: 74.17%, Test Acc: 44.44%
#   Curvature: mean=16.5540, std=34.5284
# Epoch 60/100:
#   Train Loss: 0.6564 (Class: 0.6352, Recon: 0.2124)
#   Train Acc: 71.67%, Test Acc: 44.44%
#   Curvature: mean=15.6589, std=34.0148
# Epoch 70/100:
#   Train Loss: 0.6342 (Class: 0.6102, Recon: 0.2400)
#   Train Acc: 75.42%, Test Acc: 48.15%
#   Curvature: mean=15.7172, std=34.9704
# Epoch 80/100:
#   Train Loss: 0.5628 (Class: 0.5404, Recon: 0.2234)
#   Train Acc: 78.75%, Test Acc: 48.15%
#   Curvature: mean=16.1323, std=32.9724
# Epoch 90/100:
#   Train Loss: 0.5970 (Class: 0.5746, Recon: 0.2241)
#   Train Acc: 78.75%, Test Acc: 44.44%
#   Curvature: mean=15.7104, std=33.2329
# Epoch 100/100:
#   Train Loss: 0.5902 (Class: 0.5690, Recon: 0.2116)
#   Train Acc: 75.42%, Test Acc: 44.44%
#   Curvature: mean=16.0639, std=35.5265
#
# Final Results:
#   Train Accuracy: 75.4%
#   Test Accuracy: 44.4%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.56      0.80      0.66        30
#       Improv       0.00      0.00      0.00        12
#        Scale       0.00      0.00      0.00        12
#
#     accuracy                           0.44        54
#    macro avg       0.19      0.27      0.22        54
# weighted avg       0.31      0.44      0.37        54
#
# Results saved to: /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/curvature_results/curvature_subject_48d_cv_results.pkl
#
# === Curvature Results (subject split, 48D) ===
# Accuracy: 41.5% ± 9.0%
#
# TIME SPLIT:
#
# === Curvature Model Trial 1/5 (time split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Loss: 1.0262 (Class: 0.9932, Recon: 0.3304)
#   Train Acc: 55.80%, Test Acc: 41.18%
#   Curvature: mean=17.6485, std=40.6342
# Epoch 20/100:
#   Train Loss: 0.8970 (Class: 0.8710, Recon: 0.2598)
#   Train Acc: 62.50%, Test Acc: 48.53%
#   Curvature: mean=17.5855, std=40.5751
# Epoch 30/100:
#   Train Loss: 0.8355 (Class: 0.8110, Recon: 0.2446)
#   Train Acc: 62.95%, Test Acc: 50.00%
#   Curvature: mean=15.8491, std=39.0053
# Epoch 40/100:
#   Train Loss: 0.8266 (Class: 0.8059, Recon: 0.2064)
#   Train Acc: 66.07%, Test Acc: 47.06%
#   Curvature: mean=15.7048, std=35.5462
# Epoch 50/100:
#   Train Loss: 0.7840 (Class: 0.7591, Recon: 0.2484)
#   Train Acc: 67.86%, Test Acc: 47.06%
#   Curvature: mean=15.8092, std=37.0627
# Epoch 60/100:
#   Train Loss: 0.7474 (Class: 0.7245, Recon: 0.2293)
#   Train Acc: 65.18%, Test Acc: 44.12%
#   Curvature: mean=15.5350, std=34.8890
# Epoch 70/100:
#   Train Loss: 0.7652 (Class: 0.7427, Recon: 0.2253)
#   Train Acc: 68.30%, Test Acc: 44.12%
#   Curvature: mean=15.1315, std=33.6818
# Epoch 80/100:
#   Train Loss: 0.7516 (Class: 0.7306, Recon: 0.2102)
#   Train Acc: 69.64%, Test Acc: 42.65%
#   Curvature: mean=15.0900, std=34.0672
# Epoch 90/100:
#   Train Loss: 0.7888 (Class: 0.7675, Recon: 0.2132)
#   Train Acc: 65.18%, Test Acc: 39.71%
#   Curvature: mean=15.2122, std=34.0192
# Epoch 100/100:
#   Train Loss: 0.7636 (Class: 0.7418, Recon: 0.2180)
#   Train Acc: 66.96%, Test Acc: 41.18%
#   Curvature: mean=15.0963, std=33.1180
#
# Final Results:
#   Train Accuracy: 67.0%
#   Test Accuracy: 41.2%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.47      0.71      0.56        34
#       Improv       0.50      0.06      0.11        17
#        Scale       0.20      0.18      0.19        17
#
#     accuracy                           0.41        68
#    macro avg       0.39      0.31      0.29        68
# weighted avg       0.41      0.41      0.36        68
#
#
# === Curvature Model Trial 2/5 (time split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Loss: 1.0039 (Class: 0.9718, Recon: 0.3217)
#   Train Acc: 56.70%, Test Acc: 39.71%
#   Curvature: mean=19.1345, std=43.1296
# Epoch 20/100:
#   Train Loss: 0.8597 (Class: 0.8250, Recon: 0.3480)
#   Train Acc: 64.73%, Test Acc: 51.47%
#   Curvature: mean=13.9179, std=32.4107
# Epoch 30/100:
#   Train Loss: 0.6986 (Class: 0.6677, Recon: 0.3090)
#   Train Acc: 71.43%, Test Acc: 44.12%
#   Curvature: mean=11.9486, std=28.5333
# Epoch 40/100:
#   Train Loss: 0.5879 (Class: 0.5622, Recon: 0.2560)
#   Train Acc: 73.21%, Test Acc: 39.71%
#   Curvature: mean=10.9246, std=21.7488
# Epoch 50/100:
#   Train Loss: 0.5819 (Class: 0.5583, Recon: 0.2357)
#   Train Acc: 78.57%, Test Acc: 38.24%
#   Curvature: mean=10.8367, std=21.1712
# Epoch 60/100:
#   Train Loss: 0.4802 (Class: 0.4569, Recon: 0.2330)
#   Train Acc: 82.59%, Test Acc: 36.76%
#   Curvature: mean=11.1317, std=21.8748
# Epoch 70/100:
#   Train Loss: 0.4935 (Class: 0.4731, Recon: 0.2046)
#   Train Acc: 83.93%, Test Acc: 39.71%
#   Curvature: mean=11.3065, std=22.5164
# Epoch 80/100:
#   Train Loss: 0.4666 (Class: 0.4467, Recon: 0.1985)
#   Train Acc: 82.59%, Test Acc: 41.18%
#   Curvature: mean=11.2997, std=22.2912
# Epoch 90/100:
#   Train Loss: 0.4865 (Class: 0.4659, Recon: 0.2066)
#   Train Acc: 82.14%, Test Acc: 39.71%
#   Curvature: mean=11.5139, std=22.6417
# Epoch 100/100:
#   Train Loss: 0.4792 (Class: 0.4560, Recon: 0.2318)
#   Train Acc: 83.48%, Test Acc: 41.18%
#   Curvature: mean=11.2759, std=22.4992
#
# Final Results:
#   Train Accuracy: 83.5%
#   Test Accuracy: 41.2%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.53      0.62      0.57        34
#       Improv       0.00      0.00      0.00        17
#        Scale       0.26      0.41      0.32        17
#
#     accuracy                           0.41        68
#    macro avg       0.26      0.34      0.30        68
# weighted avg       0.33      0.41      0.36        68
#
#
# === Curvature Model Trial 3/5 (time split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Loss: 0.9760 (Class: 0.9445, Recon: 0.3150)
#   Train Acc: 56.25%, Test Acc: 47.06%
#   Curvature: mean=18.9692, std=54.1264
# Epoch 20/100:
#   Train Loss: 0.8700 (Class: 0.8429, Recon: 0.2711)
#   Train Acc: 63.39%, Test Acc: 51.47%
#   Curvature: mean=17.0926, std=40.0125
# Epoch 30/100:
#   Train Loss: 0.8467 (Class: 0.8197, Recon: 0.2695)
#   Train Acc: 64.29%, Test Acc: 52.94%
#   Curvature: mean=15.2761, std=38.1711
# Epoch 40/100:
#   Train Loss: 0.7583 (Class: 0.7344, Recon: 0.2391)
#   Train Acc: 68.75%, Test Acc: 48.53%
#   Curvature: mean=15.8116, std=39.7583
# Epoch 50/100:
#   Train Loss: 0.7140 (Class: 0.6913, Recon: 0.2267)
#   Train Acc: 72.77%, Test Acc: 48.53%
#   Curvature: mean=15.4606, std=38.0069
# Epoch 60/100:
#   Train Loss: 0.6718 (Class: 0.6451, Recon: 0.2663)
#   Train Acc: 72.32%, Test Acc: 48.53%
#   Curvature: mean=15.3959, std=36.3070
# Epoch 70/100:
#   Train Loss: 0.7288 (Class: 0.7020, Recon: 0.2683)
#   Train Acc: 70.09%, Test Acc: 52.94%
#   Curvature: mean=14.8605, std=34.2886
# Epoch 80/100:
#   Train Loss: 0.6360 (Class: 0.6122, Recon: 0.2385)
#   Train Acc: 73.66%, Test Acc: 52.94%
#   Curvature: mean=14.8554, std=34.1763
# Epoch 90/100:
#   Train Loss: 0.6614 (Class: 0.6376, Recon: 0.2387)
#   Train Acc: 72.77%, Test Acc: 50.00%
#   Curvature: mean=14.9833, std=35.5271
# Epoch 100/100:
#   Train Loss: 0.6997 (Class: 0.6766, Recon: 0.2310)
#   Train Acc: 75.45%, Test Acc: 50.00%
#   Curvature: mean=14.7833, std=34.6699
#
# Final Results:
#   Train Accuracy: 75.4%
#   Test Accuracy: 50.0%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.55      0.85      0.67        34
#       Improv       0.50      0.18      0.26        17
#        Scale       0.22      0.12      0.15        17
#
#     accuracy                           0.50        68
#    macro avg       0.42      0.38      0.36        68
# weighted avg       0.45      0.50      0.44        68
#
#
# === Curvature Model Trial 4/5 (time split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Loss: 0.9664 (Class: 0.9329, Recon: 0.3353)
#   Train Acc: 56.25%, Test Acc: 47.06%
#   Curvature: mean=17.5578, std=42.3359
# Epoch 20/100:
#   Train Loss: 0.8354 (Class: 0.8090, Recon: 0.2639)
#   Train Acc: 60.71%, Test Acc: 51.47%
#   Curvature: mean=17.5068, std=48.0107
# Epoch 30/100:
#   Train Loss: 0.7727 (Class: 0.7448, Recon: 0.2790)
#   Train Acc: 69.20%, Test Acc: 45.59%
#   Curvature: mean=15.0674, std=34.8723
# Epoch 40/100:
#   Train Loss: 0.7386 (Class: 0.7163, Recon: 0.2229)
#   Train Acc: 69.20%, Test Acc: 48.53%
#   Curvature: mean=13.9757, std=33.0360
# Epoch 50/100:
#   Train Loss: 0.6992 (Class: 0.6747, Recon: 0.2448)
#   Train Acc: 72.77%, Test Acc: 51.47%
#   Curvature: mean=13.7513, std=31.6899
# Epoch 60/100:
#   Train Loss: 0.6550 (Class: 0.6314, Recon: 0.2354)
#   Train Acc: 74.55%, Test Acc: 47.06%
#   Curvature: mean=13.1015, std=30.0780
# Epoch 70/100:
#   Train Loss: 0.6261 (Class: 0.6020, Recon: 0.2413)
#   Train Acc: 73.21%, Test Acc: 45.59%
#   Curvature: mean=13.3260, std=29.5691
# Epoch 80/100:
#   Train Loss: 0.5823 (Class: 0.5577, Recon: 0.2462)
#   Train Acc: 77.68%, Test Acc: 44.12%
#   Curvature: mean=13.2973, std=29.8242
# Epoch 90/100:
#   Train Loss: 0.6142 (Class: 0.5923, Recon: 0.2199)
#   Train Acc: 73.66%, Test Acc: 50.00%
#   Curvature: mean=13.4557, std=30.8289
# Epoch 100/100:
#   Train Loss: 0.6853 (Class: 0.6624, Recon: 0.2289)
#   Train Acc: 72.32%, Test Acc: 45.59%
#   Curvature: mean=13.7389, std=30.0485
#
# Final Results:
#   Train Accuracy: 72.3%
#   Test Accuracy: 45.6%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.53      0.76      0.63        34
#       Improv       0.50      0.06      0.11        17
#        Scale       0.24      0.24      0.24        17
#
#     accuracy                           0.46        68
#    macro avg       0.42      0.35      0.32        68
# weighted avg       0.45      0.46      0.40        68
#
#
# === Curvature Model Trial 5/5 (time split, 48D) ===
# Found 17 valid subjects
#
# Total intervals extracted: 306 (expected: 306)
#
# Split results:
#   Train: 238 intervals
#   Test: 68 intervals
# Epoch 10/100:
#   Train Loss: 0.9969 (Class: 0.9694, Recon: 0.2751)
#   Train Acc: 58.04%, Test Acc: 50.00%
#   Curvature: mean=17.1705, std=39.9030
# Epoch 20/100:
#   Train Loss: 0.9303 (Class: 0.9030, Recon: 0.2729)
#   Train Acc: 60.71%, Test Acc: 51.47%
#   Curvature: mean=17.8442, std=48.8003
# Epoch 30/100:
#   Train Loss: 0.8291 (Class: 0.8003, Recon: 0.2878)
#   Train Acc: 65.18%, Test Acc: 50.00%
#   Curvature: mean=15.5294, std=38.0960
# Epoch 40/100:
#   Train Loss: 0.7713 (Class: 0.7458, Recon: 0.2548)
#   Train Acc: 68.30%, Test Acc: 51.47%
#   Curvature: mean=14.6546, std=29.6375
# Epoch 50/100:
#   Train Loss: 0.7546 (Class: 0.7301, Recon: 0.2447)
#   Train Acc: 69.20%, Test Acc: 50.00%
#   Curvature: mean=13.1858, std=25.4735
# Epoch 60/100:
#   Train Loss: 0.7342 (Class: 0.7096, Recon: 0.2464)
#   Train Acc: 70.98%, Test Acc: 47.06%
#   Curvature: mean=13.3690, std=27.2653
# Epoch 70/100:
#   Train Loss: 0.7310 (Class: 0.7085, Recon: 0.2247)
#   Train Acc: 70.09%, Test Acc: 48.53%
#   Curvature: mean=13.4784, std=27.7936
# Epoch 80/100:
#   Train Loss: 0.7341 (Class: 0.7113, Recon: 0.2275)
#   Train Acc: 71.43%, Test Acc: 48.53%
#   Curvature: mean=13.1898, std=26.4605
# Epoch 90/100:
#   Train Loss: 0.6851 (Class: 0.6623, Recon: 0.2277)
#   Train Acc: 72.77%, Test Acc: 47.06%
#   Curvature: mean=13.5036, std=27.1640
# Epoch 100/100:
#   Train Loss: 0.7713 (Class: 0.7470, Recon: 0.2431)
#   Train Acc: 68.30%, Test Acc: 48.53%
#   Curvature: mean=12.9723, std=26.3664
#
# Final Results:
#   Train Accuracy: 68.3%
#   Test Accuracy: 48.5%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Rest       0.52      0.82      0.64        34
#       Improv       0.40      0.12      0.18        17
#        Scale       0.33      0.18      0.23        17
#
#     accuracy                           0.49        68
#    macro avg       0.42      0.37      0.35        68
# weighted avg       0.44      0.49      0.42        68
#
# Results saved to: /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/curvature_results/curvature_time_48d_cv_results.pkl
#
# === Curvature Results (time split, 48D) ===
# Accuracy: 45.3% ± 3.6%
#
# ✓ Results saved to /Users/judesack/Neurospectrum_Creativity/RESULTS/cross_validation_results/curvature_results/curvature_cv_results.pkl
#
# === CROSS-VALIDATION SUMMARY ===
#
# 8D Latent Space:
#   Subject: 51.1% ± 5.1%
#   Time: 50.0% ± 0.0%
#
# 48D Latent Space:
#   Subject: 41.5% ± 9.0%
#   Time: 45.3% ± 3.6%
